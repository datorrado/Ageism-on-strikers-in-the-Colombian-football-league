# %% [markdown]
# # Ageism on Strikers in the Colombian
#
# ![alt text](FBL-EUROAMERICAN-JUNIOR-MONACO-ad0c5485a5fb31df03d0930a760b99c0-1.webp)!
#
# Age is one of the most visible and influential attributes in professional football. Clubs, fans, and decision-makers often associate youth with potential, resale value, and long-term upside, while older players are frequently perceived as being in irreversible decline. This perception is particularly relevant for strikers, a position where performance is directly measured through goals and match impact.
#
# In recent years, recruitment strategies in many leagues have increasingly favored younger attacking profiles. However, whether this preference is fully justified by on-pitch performance remains an open question. Older strikers may experience physical decline, but they also benefit from accumulated tactical knowledge, positional awareness, and decision-making efficiency.
#
# This project investigates whether age-related bias exists in the outcomes of elite strikers in the Colombian first division. Rather than analyzing all forwards, the focus is placed on the **top-performing strikers** (at least initially), defined as the top 15 goal scorers in each season. This approach ensures that the analysis centers on players who meaningfully influence competitive results.
#
# While initial exploratory visualizations incorporate other South American leagues for contextual benchmarking, all inferential and predictive analyses are restricted to Colombian league data in order to preserve league-specific consistency.

# %% [markdown]
# ## Main Research Question
#
# **Is there evidence of age-related bias in the performance outcomes and ranking positions of elite strikers in the Colombian league?**
#
# ---
# ### Sub-questions
# To address the main research question, the analysis is structured around some sub-questions:
# - How does the age distribution of top-performing strikers in the Colombian league evolve over time?
# - Is age associated with finishing rank among the top 15 goal scorers?
# - How does the probability of finishing in different top-15 positions vary across age groups?
# - Are certain age ranges more likely to appear at higher-ranking positions within the top 15?
# - Do performance patterns differ across age groups when viewed through probabilistic and clustering-based summaries?

# %% [markdown]
# Now let's actually jump to the code.

# %% [markdown]
# # Data ingestion and cleaning
# First we import the needed libraries (a lot of them came by with the development of the script) such as requests (curl_cffi is the best to bypass modern webpages) and pandas-re in order to clean the information onto the different datasets

# %% [markdown]
# ## Imports and dependencies
#
# Here I load libraries for:
# - **ETL** (pandas/numpy)
# - **web scraping** (requests/curl_cffi/Selenium)
# - **HTML parsing** (BeautifulSoup, lxml)
# - **EDA/modeling** (seaborn, statsmodels, sklearn)
#
# > Recommendation: as the notebook grows, group imports by theme (ETL / scraping / modeling).

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip

# %%
# !{sys.executable} -m pip install lxml

# %%
# !{sys.executable} -m pip install beautifulsoup4 html5lib

# %%
import pandas as pd
import numpy as np
import requests
import re
import time
from io import StringIO
from curl_cffi import requests as cureq
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import os
import math
from scipy.stats import norm
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import time
from io import StringIO
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# ## League configuration and URLs
#
# A dictionary with per-league metadata (country, name, source, and a function that builds the season URL). This allows **reuse** the pipeline by changing only `league_key` and `season`.

# %%
LEAGUES = {
    "COL_FPC": {
        "country": "COL",
        "league": "Primera A (COL)",
        "source": "fbref",
        "url_fn": lambda season: f"https://fbref.com/en/comps/41/{season}/stats/{season}-Primera-A-Stats",
    },
    "BRA_SERIEA": {
        "country": "BRA",
        "league": "Serie A (BRA)",
        "source": "fbref",
        "url_fn": lambda season: f"https://fbref.com/en/comps/24/{season}/stats/{season}-Serie-A-Stats",
    }
    ,
    "ARG_SA": {
        "country": "ARG",
        "league": "Superliga (ARG)",
        "source": "fbref",
        "url_map":{
            "2016": "https://fbref.com/en/comps/21/2016/stats/2016-Liga-Profesional-Argentina-Stats",
            "2018-2019": "https://fbref.com/en/comps/21/2018-2019/stats/2018-2019-Liga-Profesional-Argentina-Stats",
            "2019-2020": "https://fbref.com/en/comps/21/2019-2020/stats/2019-2020-Liga-Profesional-Argentina-Stats",
            "2021":"https://fbref.com/en/comps/21/2021/stats/2021-Liga-Profesional-Argentina-Stats",
            "2023":"https://fbref.com/en/comps/21/2023/stats/2023-Liga-Profesional-Argentina-Stats",
    }}
    ,
    "ARG_SA_LS": {
        "country": "ARG",
        "league": "Superliga (ARG)",
        "source": "livefutbol",
        # season puede ser 2016, "2016-2017", "2025-apertura", etc.
        "url_map": {
            "2015": "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se16954/2015/statistics-goals/",
            "2016-2017": "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se21890/2016-2017/statistics-goals/",
            "2017-2018": "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se24540/2017-2018/statistics-goals/",
            "2022": "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se45774/2022/statistics-goals/",
            "2024": "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se69263/2024/statistics-goals/",
            "2025-apertura": "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se84014/2025-apertura/statistics-goals/",
            "2025-clausura": "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se95472/2025-clausura/statistics-goals/",
        }
    },
}

# %% [markdown]
# ## Base scraper for FBref
#
# Function that fetches the HTML from FBref.
# - **Why Selenium:** FBref sometimes blocks simple requests or returns incomplete HTML.
# - **Key parameter:** `wait` to respect timing and reduce blocking.
# - **Output:** raw HTML as a string, which you later parse with `pd.read_html` / BeautifulSoup.

# %%
def fetch_fbref(url, wait=8):
    options = Options()
    options.add_argument("--start-maximized")
    options.add_argument("--disable-gpu")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--remote-allow-origins=*")
    options.add_argument("--incognito")

    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=options
    )

    try:
        driver.get(url)
        WebDriverWait(driver, 20).until(
            lambda d: d.execute_script("return document.readyState") == "complete"
        )
        time.sleep(wait)
        return driver.page_source
    finally:
        driver.quit()

# %%
url = f"https://fbref.com/en/comps/41/2025/stats/2025-Primera-A-Stats"
html = fetch_fbref(url)
tables = pd.read_html(StringIO(html))
len(tables)

# %%
def inject_commented_tables(html: str, must_contain=("stats_standard",)): #FBref hides the tables in comments instead of common table tags
    comments = re.findall(r"<!--(.*?)-->", html, flags=re.S) #looks for comments
    blocks = []
    for c in comments: #search for all comments
        if "<table" in c and all(m in c for m in must_contain): #stats_standard is their way of labelling their tables for standard metrics
            blocks.append(c)
    return html + "\n".join(blocks), blocks #html fetched tables and hidden tables

# %%
# Function to identify if a DataFrame is a player stats table, as FBRef update constantly their format for their tables. 
def is_player_stats_table(df: pd.DataFrame) -> bool:
    if isinstance(df.columns, pd.MultiIndex):
        cols = set(str(c).lower() for c in df.columns.get_level_values(-1))
    else:
        cols = set(str(c).lower() for c in df.columns)
    
    required_any = [
        {"player", "squad", "age"},
        {"player", "team", "age"},
        {"player", "pos", "age"},
        {"player", "position", "age"}
    ]

    return any(req.issubset(cols) for req in required_any)

# %%
"""### Extracting commented tables on FBref

FBref often hides tables inside HTML comments (`<!-- ... -->`).
This function:
1) extracts commented blocks,
2) filters those that contain relevant tables (`stats_standard`),
3) re-injects them so that BeautifulSoup / `read_html` can “see” them.

**Result:** “visible” HTML + a list of extracted blocks.
    """
def extract_stats_standard_table(html: str) -> pd.DataFrame:
    html2, _ = inject_commented_tables(html, must_contain=("stats_standard",))
    
    soup = BeautifulSoup(html2, "lxml")
    table = soup.find("table", {"id": "stats_standard"})
    if table is None:
        return None
    
    df = pd.read_html(StringIO(str(table)))[0]
    return df

# %%
# Takes the HTML (after comment injection), locates the table by `id='stats_standard'`, and converts it into a DataFrame.
def fetch_tables(years, sleep=3):
  RAW_DIR = "./data_raw"
  os.makedirs(RAW_DIR, exist_ok=True)

  data_by_year = {}
  for year in years:
    url = f"https://fbref.com/en/comps/24/{year}/stats/" #https://fbref.com/en/comps/41/{year}/stats/{year}-Primera-A-Stats"
    try:
      html = fetch_fbref(url)
    except Exception as e:
      print(f"Error fetching {year}: {e}")
      continue
    
    player_table = extract_stats_standard_table(html)

    if player_table is None:
      print(f"No player stats table found for {year}")
      continue

    filename = f"BRA_players_{year}.csv"
    filepath = os.path.join(RAW_DIR, filename)
    player_table.to_csv(filepath, index=False)
    print(f" Saved {filename} | shape = {player_table.shape}")

    data_by_year[year] = player_table

    time.sleep(sleep)

# %% [markdown]
# ## Alternative source (LiveFutbol / Livescore)
#
# When a league/source does not provide all variables (e.g., age), one can enrich the dataset with another source here.
# As the argentine league doesn't provide individual player information for multiple years, I've decided to search other sources. The idea is to **merge by player** using a `birth_year_map` (one cell below) or another key to reconstruct age.

# %%
birth_year_map = {
    # ya tenías
    "José Sand": 1980,
    "Darío Benedetto": 1990,
    "Sebastián Driussi": 1996,
    "Ramón Ábila": 1990,
    "Fernando Cavenaghi": 1983,
    "Marco Rubén": 1986,
    "Carlos Luna": 1982,
    "Ignacio Scocco": 1985,
    "Miguel Borja": 1993,
    "Mateo Retegui": 1999,
    "Claudio Bieler": 1982,

    # añadidos (muy conocidos)
    "Lucas Alario": 1992,
    "Gustavo Bou": 1990,
    "Darío Cvitanich": 1984,
    "Mariano Pavone": 1982,
    "Nicolás Blandi": 1990,
    "Emiliano Rigoni": 1993,
    "Fernando Zampedri": 1988,
    "Lautaro Martínez": 1997,
    "Mauro Zárate": 1987,
    "Santiago García": 1990,
    "Martín Cauteruccio": 1987,
    "Walter Bou": 1993,
    "Ignacio Malcorra": 1987,
    "Franco Jara": 1988,
    "Guido Carrillo": 1991,
    "Leandro Fernández": 1991,
    "Maximiliano Rodríguez": 1981,
    "Jonathan Calleri": 1993,
    "Marcelo Larrondo": 1987,
    "Enrique Triverio": 1988,
    "Lucas Albertengo": 1991,
    "Gervasio Núñez": 1986,
    "Fernando Coniglio": 1991,
    "Sebastián Palacios": 1992,
    "Javier Correa": 1994,
    "Sebastián Ribas": 1988,
    "Franco Soldano": 1994,
    "Fernando Márquez": 1991,
    "Ignacio Pussetto": 1995,
    "Cristian Lema": 1988,
    "Nicolás Fernández": 1996,
    "Enzo Copetti": 1998,
    "Adam Bareiro": 1996,
    "Renzo Lopez": 1994,
    "Blas Armoa": 1998,
    "Cristian Colmán": 1994,
    "Luis Rodríguez": 1991,
    "Mauro Boselli": 1981,
    "Ramiro Carrera": 1993,
    "Alejandro Martinez": 1992,
    "Braian Romero": 1991,
    "Mateo Pellegrino": 2000,
    "Milton Giménez": 1994,
    "Claudio Aquino": 1984,
    "Gabriel Avalos": 1993,
    "Jonathan Herrera": 1989,
    "Salomón Rodríguez": 1990,
    "Facundo Colidio": 1998,
    "Miguel Merentiel": 1996,
    "Bruno Barticciotto": 2001,
    "Adrián Martinez": 1992,
    "Tomás Molina": 1995,
    "Andrés Vombergar": 1994,
    "Elías Torres": 2000,
    "Jhonatan Candia": 1995,
    "Matko Miljevic": 1998,
    "Leonardo Heredia": 1996,
    "Alex Luna": 2002,
    "Facundo Bruera": 1998,
    "Ignacio Russo": 2001,
    "Gaston Togni": 1997,
    "Ronaldo Martinez": 1996,
    "Maria Angel": 1997,
    "Marcelo Torres": 1993,
    "Rodrigo Castillo": 1995,
    "Alexis Cuello": 1994,
    "Giuliano Galoppo": 1996,
    "Alejo Veliz": 2000,
    "Abiel Osorio": 1997,
    "Agustín Auzmendi": 1997,
    "Felipe Loyola": 1999,
    "Ángel Di María": 1988,
    "Juan Miritello": 1999,
    "Alejandro Gagliardi": 1989,
}

# %%
"""Creates a `driver` with options (headless, incognito, no-sandbox, etc.).
Centralizing this avoids duplicated configuration and makes it easier to adjust if you get blocked."""
def make_driver(headless=False):
    options = Options()
    if headless:
        options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-gpu")
    options.add_argument("--incognito")
    options.add_argument("--window-size=1400,900")
    return webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %% [markdown]
# ## Robust reading of the top-scorers table
#
# From `page_source`, tries to identify the correct table using typical columns.
# This matters because LiveFutbol can contain multiple tables (or banners), and `read_html` often returns more than one.

# %%
def read_goals_table_from_current_page(driver):
    html = driver.page_source
    tables = pd.read_html(StringIO(html))

    # tries to choose the goalscorers table by typical columns
    for t in tables:
        cols = [str(c).strip().lower() for c in t.columns]

        # “goles/goals/tore” must exist
        has_goals = any(c in cols for c in ["goles", "goals", "tore"])

        # and the table must have a player-type column
        has_player = any(c in cols for c in ["jugador", "player", "spieler"])

        if has_goals and has_player:
            return t

    # fallback: primera tabla
    return tables[0] if tables else None

def season_label_to_year(label: str) -> int | None: #helper to extract year from season label (as the league varies: "2015" or "2015-2016" or "2025-apertura")
    m = re.findall(r"(20\d{2})", label)
    if not m:
        return None
    return int(m[-1])  # last year that appears in the label to use as season

def split_player_team_simple(s: str):
    """
    From a string like:
    'D. BenedettoDarío BenedettoBoca Juniors'
    returns:
    ('Darío Benedetto', 'Boca Juniors')
    """
    if not isinstance(s, str):
        return None, None

    # identify accented and/or capitalized words
    words = re.findall(r"[A-ZÁÉÍÓÚÑ][a-záéíóúñ]+", s)

    if len(words) < 3:
        return s.strip(), None

    # player = 2nd and 3rd word
    player = " ".join(words[1:3])

    # team = from 5th word onwards (if exists)
    if len(words) >= 5:
        team = " ".join(words[3:])
    else:
        team = words[-1]
    
    return player, team


def clean_livefutbol_goals(df_raw: pd.DataFrame, season_label, country="ARG"):
    df = df_raw.copy()
    df.columns = [str(c).strip() for c in df.columns]

    rename_map = {
        "Spieler": "player",
        "Jugador": "player",
        "Player": "player",

        "Goles": "goals",
        "Goals": "goals",
        "Tore": "goals",

        "Elfm.": "pen_goals",
        "11m": "pen_goals",
        "Pen.": "pen_goals",

        "Juegos": "matches_played",
        "Einsätze": "matches_played",
        "mathches": "matches_played",
    }
    df = df.rename(columns={c: rename_map.get(c, c) for c in df.columns})

    keep = [c for c in ["player", "matches_played","goals", "pen_goals"] if c in df.columns]
    df = df[keep].copy()

    for c in ["goals", "pen_goals"]:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce").fillna(0).astype(int)

    df["season"] = season_label_to_year(season_label)
    df["country"] = country
    df[["player", "team"]] = df["player"].apply(lambda x:  pd.Series(split_player_team_simple(x)))
    
    return df.dropna(subset=["season"])

# %% [markdown]
# ## Extracting Top 15 per season
#
# Function that:
# 1) opens the season URL,
# 2) reads the top-scorers table,
# 3) cleans it and returns the Top 15 with minimal variables (goals, position/rank, etc.).

# %%
def top15_from_livefutbol(driver, season_label, url: str, country="ARG"):
    driver.get(url)
    time.sleep(0.8)

    raw = read_goals_table_from_current_page(driver)
    if raw is None:
        return None

    df = clean_livefutbol_goals(raw, season_label, country=country)
    season = season_label_to_year(season_label)
    if season == 2025:
        df = df.sort_values(["goals", "pen_goals"], ascending=False).head(30).copy()
    else:
        df = df.sort_values(["goals", "pen_goals"], ascending=False).head(15).copy()
    df["goal_rank"] = range(1, len(df) + 1)
    return df

# %% [markdown]
# ## Resolving the URL by source
#
# Abstracts the data origin:
# - if the source is `fbref`, use `url_fn(season)`
# - if the source is `livefutbol`, use `url_map`
#
# This way the rest of the pipeline does not depend on the specific source.

# %%
def resolve_url(league_key: str, season) -> str:
    meta = LEAGUES[league_key]
    if meta["source"] == "fbref":
        return meta["url_fn"](season)
    if meta["source"] == "livefutbol":
        return meta["url_map"][str(season)]
    raise ValueError(f"Unknown source for {league_key}: {meta['source']}")

# %% [markdown]
# ## Normalizing MultiIndex columns
#
# Many tables come with MultiIndex (two-level) columns.
# Here you “flatten” them to obtain stable names, making renaming/selection more reliable.

# %%
def flatten_multiindex_join_levels(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    lvl0 = df.columns.get_level_values(0)
    lvl1 = df.columns.get_level_values(1)

    new_cols = []
    for a, b in zip(lvl0, lvl1):
        if str(a).startswith("Unnamed"):
            a = ""
        else:
            a = str(a).strip().replace(" ", "_")

        b = str(b).strip().replace(" ", "_")

        new_cols.append(f"{a}_{b}" if a else b)

    df.columns = new_cols
    return df

# %% [markdown]
# ## Cleaning and standardizing stats
#
# Main cleaning function:
# - flattens columns,
# - renames to a consistent convention,
# - converts types (age/minutes/goals),
# - removes non-player rows.
#
# **Goal:** the final dataset should be model-ready without later hacks.

# %%
def clean_player_stats(df_raw: pd.DataFrame) -> pd.DataFrame:
  df = df_raw.copy()

  df = flatten_multiindex_join_levels(df)


    #mapping columns into a better convention
  rename_map = {
        "Player": "player",
        "Nation": "nation",
        "Pos": "position",
        "Squad": "team",
        "Age": "age",
        "Born": "born",
        "Playing_Time_MP": "matches_played",
        "Playing_Time_Starts": "starts",
        "Playing_Time_Min": "minutes",
        "Playing_Time_90s": "nineties",
        "Performance_Gls": "goals",
        "Performance_Ast": "assists",
        "Performance_G+A": "G+A",
        "Per_90_Minutes_Gls": "goals_per_90",
        "Per_90_Minutes_Ast": "assists_per_90",
        "Per_90_Minutes_G+A": "G+A_per_90"
    }

  df = df.rename(columns=rename_map)
  #formatting columns to a numerical format
  numeric_cols = [
        "age", "born", "matches_played", "starts", "minutes", "nineties",
        "goals", "assists", "goals_per_90", "assists_per_90"
  ]

  for c in numeric_cols:
    if c in df.columns:
      df[c] = pd.to_numeric(df[c], errors="coerce")

  print(df.columns.tolist())
  df = df[df["minutes"].fillna(0)>0]

  final_cols = [
        "player",
        "team",
        "position",
        "age",
        "matches_played",
        "minutes",
        "goals",
        "goals_per_90",
        "assists",
        "G+A",
        "assists_per_90",
        "Performance_G-PK",
    ]

  df = df[[c for c in final_cols if c in df.columns]]
  return df

# %%
def postprocess_livefutbol_2025(df_live: pd.DataFrame) -> pd.DataFrame:
    df = df_live.copy()

    # normaliza season a int si viene como string
    df["season"] = pd.to_numeric(df["season"], errors="coerce")

    # 2025: sumar goles por jugador (A+C) y quedarse con top15 final
    df_2025 = df.query("season == 2025").copy()
    df_rest = df.query("season != 2025").copy()

    if len(df_2025):
        df_2025 = (
            df_2025
            .groupby(["player"], as_index=False)
            .agg({
                "goals": "sum",
                "pen_goals": "sum",
                "team": "first",
                "country": "first",
            })
            .sort_values(["goals","pen_goals"], ascending=False)
            .head(15)
            .copy()
        )
        df_2025["season"] = 2025
        df_2025["goal_rank"] = range(1, len(df_2025)+1)
    df_all = pd.concat([df_rest, df_2025], ignore_index=True)
    df_all["birth_year"] = df_all["player"].map(birth_year_map)
    df_all["age"] = df_all["season"] - df_all["birth_year"]
    df_all = df_all.drop(columns=["birth_year"])
    
    return df_all

# %%
def align_live_to_fbref(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    
    if "pen_goals" in df.columns:
        df["Performance_G-PK"] = df["goals"] - df["pen_goals"]
        df.drop(columns=["pen_goals"], inplace=True)
    else:
        df["Performance_G-PK"] = df["goals"]
    
    for c in ["position","minutes","goals_per_90","assists","G+A","assists_per_90","G+A_per_90","starts","nineties","nation","born", "age", "league", "league_key", "source"]:
        if c not in df.columns:
            df[c] = np.nan
    
    cols = [
        "player","team","position","age","matches_played","minutes",
        "goals","pen_goals","Performance_G-PK",
        "goals_per_90","assists","G+A","assists_per_90",
        "season","goal_rank",
    ]

    for c in cols: 
        if c not in df.columns:
            df[c] = np.nan
    return df[cols]

# %%
META_COLS = ["country", "league", "source", "league_key"]

def fetch_clean_tables(league_key: str, driver):
    meta = LEAGUES[league_key]
    #url = resolve_url(LEAGUES, league_key, season)
    RAW_DIR = "./data_clean"
    os.makedirs(RAW_DIR, exist_ok=True)
    if meta["source"] == "fbref":
        if not league_key.startswith("ARG"):    
            years = list(range(2015, 2026))
            df_raw = None
            for year in years:
                url = meta["url_fn"](year) #fhttps://fbref.com/en/comps/41/{year}/stats/{year}-Primera-A-Stats"
                try:
                    html = fetch_fbref(url)
                except Exception as e:
                    print(f"Error fetching {year}: {e}")
                    continue
                
                player_table = extract_stats_standard_table(html)

                if player_table is None:
                    print(f"No player stats table found for {year}")
                    continue
                df_live = player_table
                df_live = clean_player_stats(df_live)
                df_live["season"] = year
                df_raw = pd.concat([df_raw, df_live]) if df_raw is not None else df_live

                time.sleep(2)
            filename = f"{league_key}_players_stats_raw.csv"
            filepath = os.path.join(RAW_DIR, filename)
            df_raw.to_csv(filepath, index=False)
            print(f" Saved {filename} | shape = {df_raw.shape}")
        else:
            df_raw = None
            for season in meta["url_map"].keys():
                url = meta["url_map"][season]
                print(url)
                try:
                    html = fetch_fbref(url)
                except Exception as e:
                    print(f"Error fetching {season}: {e}")
                    continue
                player_table = extract_stats_standard_table(html)
                if player_table is None:
                    print(f"No player stats table found for {season}")
                    continue
                df_live = player_table
                df_live = clean_player_stats(df_live)
                df_live["season"] = season_label_to_year(season)
                df_raw = pd.concat([df_raw, df_live]) if df_raw is not None else df_live
                time.sleep(2)
            filename = f"{league_key}_players_stats_raw.csv"
            filepath = os.path.join(RAW_DIR, filename)
            df_raw.to_csv(filepath, index=False)
            print(f" Saved {filename} | shape = {df_raw.shape}")
    elif meta["source"] == "livefutbol":
        if driver is None:
            raise ValueError("Livefutbol requires Selenium driver.")
        
        df_raw = None
        for season in meta["url_map"].keys():
            url = meta["url_map"][season]
            players_table = top15_from_livefutbol(driver, season, url, country=meta["country"])
            df_raw = pd.concat([df_raw, players_table]) if df_raw is not None else players_table
        filename = f"{league_key}_top15_raw.csv"
        filepath = os.path.join(RAW_DIR, filename)
        df_raw = postprocess_livefutbol_2025(df_raw)
        df_raw = align_live_to_fbref(df_raw)
        df_raw.to_csv(filepath, index=False)
        print(f" Saved {filename} | shape = {df_raw.shape}")

        
        
        
    # inyecta metadata SIEMPRE
    df_raw = df_raw.copy()
    df_raw["country"] = meta["country"]
    df_raw["league"] = meta["league"]
    df_raw["source"] = meta["source"]
    df_raw["league_key"] = league_key
    #df_raw["url"] = url
    return df_raw

# %%
df_arg_fb = fetch_clean_tables("ARG_SA", make_driver(headless=True))
df_col = fetch_clean_tables("COL_FPC", None)
df_bra = fetch_clean_tables("BRA_SERIEA", None)

# %%
filename = "ARG_SA_players_stats.csv"
filepath = os.path.join('./data_clean', filename)
df_arg_fb.to_csv(filepath, index=False)
df_arg_fb.head()
# Out:
#              player              team position   age  matches_played  minutes  \
# 0  Luciano Abecasis        Godoy Cruz       DF  25.0            15.0   1345.0
# 1     Mathías Abero  Atlético Rafaela    DF,MF  25.0            12.0    733.0
# 2       Ramón Ábila           Huracán       FW  26.0            15.0   1321.0
# 3    Nelson Acevedo             Unión       MF  27.0            13.0   1027.0
# 4  Guillermo Acosta      Atlé Tucumán    DF,MF  27.0            13.0    922.0
#
#    goals  goals_per_90  assists G+A  assists_per_90 Performance_G-PK season
# 0    0.0          0.00      3.0   3            0.20                0   None
# 1    1.0          0.12      0.0   1            0.00                1   None
# 2   11.0          0.75      1.0  12            0.07               11   None
# 3    1.0          0.09      0.0   1            0.00                1   None
# 4    2.0          0.20      1.0   3            0.10                2   None

# %%
df_col.head()
# Out:
#              player             team position   age  matches_played  minutes  \
# 0     Carlos Abella            Huila       GK  29.0             7.0    630.0
# 1      Camilo Acero         Cortuluá       GK  20.0             1.0     90.0
# 2     Alonso Acosta      Uniautónoma       DF  25.0            29.0   2564.0
# 3  Sebastián Acosta     Patriotas FC       MF  20.0             5.0    106.0
# 4      Héctor Acuña  Deportes Tolima       FW  33.0            13.0    568.0
#
#    goals  goals_per_90  assists G+A  assists_per_90 Performance_G-PK country  \
# 0    0.0          0.00      0.0   0             0.0                0     COL
# 1    0.0          0.00      0.0   0             0.0                0     COL
# 2    0.0          0.00      0.0   0             0.0                0     COL
# 3    0.0          0.00      0.0   0             0.0                0     COL
# 4    1.0          0.16      0.0   1             0.0                1     COL
#
#             league source league_key
# ...

# %%
df_bra.head()
# Out:
#                 player           team position   age  matches_played  minutes  \
# 0                Abuda    Chapecoense       MF  26.0             4.0    221.0
# 1           Adrianinho    Ponte Preta       MF  34.0             4.0    114.0
# 2  João Afonso Crispim    Chapecoense       MF  19.0             3.0    110.0
# 3         Bruno Aguiar      Joinville       DF  28.0            18.0   1620.0
# 4               Aislan  Vasco da Gama    DF,MF  27.0             4.0    233.0
#
#    goals  goals_per_90  assists G+A  assists_per_90 Performance_G-PK country  \
# 0    0.0          0.00      1.0   1            0.41                0     BRA
# 1    0.0          0.00      0.0   0            0.00                0     BRA
# 2    0.0          0.00      0.0   0            0.00                0     BRA
# 3    2.0          0.11      0.0   2            0.00                2     BRA
# 4    0.0          0.00      0.0   0            0.00                0     BRA
#
# ...

# %%
df_arg_ls = fetch_clean_tables("ARG_SA_LS", make_driver(headless=True))
# Out:
#  Saved ARG_SA_LS_top15_raw.csv | shape = (90, 15)

# %%
# In case you want to reload the saved data:
df_arg_ls = pd.read_csv('./data_clean/ARG_SA_LS_top15_raw.csv')
df_arg_fb = pd.read_csv('./data_clean/ARG_SA_players_stats_raw.csv')
df_col = pd.read_csv('./data_clean/COL_FPC_players_stats_raw.csv')
df_bra = pd.read_csv('./data_clean/BRA_SERIEA_players_stats_raw.csv')

# %% [markdown]
# ## Data consolidation and aggregation
#
# When a player appears multiple times in the same season (due to mid-season transfers or multiple tournament phases), their statistics must be aggregated to obtain a single seasonal record.
#
# The `consolidate_player_stats()` function addresses this by:
#
# - **Summing activity-based metrics** (minutes, goals, assists) across all appearances
# - **Concatenating team names** when a player has represented multiple clubs
# - **Recalculating per-90 ratios** after aggregation to ensure metric consistency
#
# This ensures that each player-season pair corresponds to a single observation, which is critical for ranking-based analyses and modeling.

# %%
def consolidate_player_stats(df):
    # Defining how we want to aggregate each column
    agg_rules = {
        'team': lambda x: " / ".join(dict.fromkeys(x)), # Elimina duplicados y une con /
        'position': lambda x: ",".join(sorted(set(x))),         # Usualmente la posición no cambia
        'age': 'max',                # La edad máxima alcanzada en ese año
        'matches_played': 'sum',     # Sumamos actividad
        'minutes': 'sum',            # Sumamos actividad
        'goals': 'sum',              # Sumamos actividad
        'assists': 'sum',            # Sumamos actividad
        'G+A': 'sum',               # Sumamos actividad
        'Performance_G-PK': 'sum',   # Sumamos actividad
        # Las columnas de ratios (per 90) se recalculan después
    }

    df_grouped = df.groupby(['player', 'season'], as_index=False).agg(agg_rules)

    df_grouped['goals_per_90'] = (df_grouped['goals'] / df_grouped['minutes'] * 90).round(2)
    df_grouped['assists_per_90'] = (df_grouped['assists'] / df_grouped['minutes'] * 90).round(2)
    df_grouped['G+A_per_90'] = (df_grouped['G+A'] / df_grouped['minutes'] * 90).round(2)
    df_grouped = df_grouped.sort_values(by=['season', 'player'], ascending=[True, True])
    return df_grouped

# %%
df_col = consolidate_player_stats(df_col)

# %%
df_arg_fb = consolidate_player_stats(df_arg_fb)

# %%
df_bra = consolidate_player_stats(df_bra)

# %% [markdown]
# ## Why Compare Multiple Leagues Only in the Exploratory Stage?
#
# Although the core objective of this project is to analyze age-related performance patterns in the Colombian first division, the exploratory analysis initially includes three South American leagues: Colombia, Argentina, and Brazil.
#
# This choice is intentional and methodological rather than accidental.
#
# Argentina and Brazil consistently produce and attract some of the most prolific strikers in South America. As a result, they serve as high-performance reference leagues, allowing the Colombian league to be contextualized within a broader regional ecosystem.
#
# Including these leagues at the exploratory stage serves three purposes:
#
# 1. **Contextual Benchmarking**
#    Observing age trends in stronger striker markets helps determine whether patterns observed in Colombia are unique or part of a wider regional phenomenon.
#
# 2. **Signal Validation**
#    If similar age-related dynamics appear across leagues of different competitive levels, this strengthens the argument that the observed effects are structural rather than data artifacts.
#
# 3. **Narrative Framing**
#    The comparison allows the project to begin with a broader question — *how age relates to striker productivity in South America* — before narrowing down to a focused, league-specific analysis.
#
# However, for all inferential models and predictive tasks, the analysis deliberately restricts itself to Colombian league data. This ensures internal consistency and avoids conflating league-specific dynamics such as tactical styles, transfer behavior, and squad construction strategies.
#
# In short, cross-league comparisons are used to **frame the problem**, while Colombian data is used to **answer it**.

# %% [markdown]
# ## Building the top-scorers dataset
#
# In this section you define how you select the Top N per season (by goals) and how you break ties (`untie`).
# This is where you decide **what it means to be Top 15** in your study.

# %% [markdown]
# ### Creation of the top scorers dataset
# Basic function to obtain the amount of top scorers you want to examine. Particularly, the untie method is just taking into account which player had the most non-penalty goals, as I consider that a more proper approximation of goalscoring capacity should be based on open-play actions.

# %%
def top_scorers(league_key: str, clean_df: pd.DataFrame, top_n: int = 15):
    required_cols = {"season", "goals", "Performance_G-PK", "minutes"}
    missing = required_cols - set(clean_df.columns)
    if missing:
        raise ValueError(f"Faltan columnas en el DataFrame: {missing}")

    # Orden + Top N por temporada
    top_df = (
        clean_df
        .groupby("season", group_keys=False)
        .apply(lambda g: g.sort_values(
            by=["goals", "Performance_G-PK", "minutes"],
            ascending=[False, False, True]
        ).head(top_n))
        .reset_index(drop=True)
    )

    # Rank dentro de cada temporada (1..N)
    top_df["goal_rank"] = top_df.groupby("season")["goals"].rank(
        method="first",
        ascending=False
    ).astype(int)

    # Guardar archivo
    os.makedirs("./data_ready", exist_ok=True)
    filename = f"{league_key}_top{top_n}_scorers.csv"
    path = f"./data_ready/{filename}"
    top_df.to_csv(path, index=False)

    print(f"Saved: {path}")
    return top_df

# %%
COL_top15 = top_scorers("COL", df_col)
BRA_top15 = top_scorers("BRA", df_bra)
ARG_top15 = top_scorers("ARG", df_arg_fb)
# Out:
# Saved: ./data_ready/COL_top15_scorers.csv
# Saved: ./data_ready/BRA_top15_scorers.csv
# Saved: ./data_ready/ARG_top15_scorers.csv
# C:\Users\david\AppData\Local\Temp\ipykernel_41064\771466263.py:11: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.sort_values(
# C:\Users\david\AppData\Local\Temp\ipykernel_41064\771466263.py:11: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...

# %%
df_arg_top15_all = (
    pd.concat([ARG_top15, df_arg_ls], ignore_index=True)
      .sort_values(["season", "goal_rank"], na_position="last")
      .reset_index(drop=True)
)

# %%
filename = "ARG_top15_scorers.csv"
filepath = os.path.join('./data_ready', filename)
df_arg_top15_all.to_csv(filepath, index=False)

# %%
def build_age_timeseries(df, top_n = 15, rank_col="goals"):
  df_sorted = df.sort_values(["season", rank_col], ascending=[True, False])

  df_top = df_sorted.groupby("season", as_index=False).head(top_n)

  ts = (
      df_top.groupby("season", as_index=False)
      .agg(
          mean_age =("age","mean"),
          median_age = ("age", "median"),
          p75_age = ("age", lambda s: s.quantile(0.75)),
          n_players = ("player","nunique")
      ).sort_values("season")
  )
  return ts, df_top

# %%
ARG_age_ts, ARG_top15_detailed = build_age_timeseries(df_arg_top15_all, top_n=15, rank_col="goal_rank")
BRA_age_ts, BRA_top15_detailed = build_age_timeseries(BRA_top15, top_n=15, rank_col="goal_rank")
COL_age_ts, COL_top15_detailed = build_age_timeseries(COL_top15, top_n=15, rank_col="goal_rank")

# %%
ARG_age_ts.head()
# Out:
#    season   mean_age  median_age  p75_age  n_players
# 0    2015  28.266667        28.0     30.5         15
# 1    2016  26.266667        27.0     27.5         15
# 2    2017  28.400000        27.0     32.5         15
# 3    2018  27.400000        28.0     30.0         15
# 4    2019  29.066667        28.0     32.0         15

# %%
COL_age_ts.head()
# Out:
#    season   mean_age  median_age  p75_age  n_players
# 0    2015  24.666667        25.0     27.0         15
# 1    2016  25.666667        26.0     28.0         15
# 2    2017  27.533333        28.0     30.0         15
# 3    2018  27.733333        29.0     29.0         15
# 4    2019  26.866667        27.0     29.0         15

# %%
BRA_age_ts.head()
# Out:
#    season   mean_age  median_age  p75_age  n_players
# 0    2015  25.666667        25.0     29.5         15
# 1    2016  27.866667        28.0     32.5         15
# 2    2017  28.466667        27.0     31.0         15
# 3    2018  25.800000        25.0     28.0         15
# 4    2019  27.200000        27.0     29.5         15

# %%
ARG_age_ts["period"] = (ARG_age_ts["season"] > 2020).astype(int)
COL_age_ts["period"] = (COL_age_ts["season"] > 2020).astype(int)
BRA_age_ts["period"] = (BRA_age_ts["season"] > 2020).astype(int)

# %%
plt.figure()

sns.lineplot(data=ARG_age_ts, x="season", y="mean_age", marker="o", label="Argentina")
sns.lineplot(data=COL_age_ts, x="season", y="mean_age", marker="o", label="Colombia")
sns.lineplot(data=BRA_age_ts, x="season", y="mean_age", marker="o", label="Brasil") 

plt.axvline(2020, linestyle="--", color="gray")
plt.title("Mean Age of Top 15 Scorers Over Seasons")
plt.xlabel("Season")
plt.ylabel("Mean Age")
plt.legend()
plt.show()

# %% [markdown]
# Although the average age of top scorers in the Colombian league has declined slightly in the most recent seasons, it remains notable that the post-pandemic period coincides with the highest average ages observed in the sample.
#
# This peak suggests a temporary shift in which experienced strikers played a disproportionately central role in offensive production. In a context marked by economic uncertainty and reduced transfer activity, clubs may have relied more heavily on proven, domestic or veteran profiles rather than younger, developmental options.
#
# When viewed alongside Argentina and Brazil, this pattern becomes more informative. While all three leagues exhibit fluctuations rather than a monotonic age trend, Colombia shows a more pronounced post-pandemic increase in the average age of its top scorers. In contrast, Argentina and Brazil display comparatively smoother trajectories, with lower volatility and less extreme peaks.
#
# This divergence reinforces the idea that the Colombian league experienced a period in which experience temporarily outweighed youth as a determinant of striker impact, highlighting how structural and contextual factors can shape age-related performance outcomes beyond individual decline.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import importlib
import graphics.timeseries as ts
importlib.reload(ts)

series = {
    "Argentina": ARG_age_ts,
    "Colombia":  COL_age_ts,
    "Brasil":    BRA_age_ts
}

# Colores “team colors” (ajústalos a tu gusto)
colors = {
    "Argentina": "#75AADB",
    "Colombia":  "#FCD116",
    "Brasil":    "#009C3B"
}

flags = {
    "Argentina": "flags/arg.png",
    "Colombia":  "flags/col.png",
    "Brasil":    "flags/bra.png"
}

ts.plot_xdatafc_mean_age(
    series_dict=series,
    colors=colors,
    flag_paths=flags,
    logo_path="branding/xdatafc.png",            # tu logo (como la 2da imagen)
    title="Mean Age of Top 15 Scorers Over Seasons",
    vline_year=2020,
    outpath="./data_ready/xdatafc_mean_age_top15.png",
    point_logo_zoom=0.035,
    corner_logo_zoom=0.095,
    corner_logo_xy=(0.9999, 0.9999)
)
# Out:
# (<Figure size 1050x580 with 1 Axes>,
#  <Axes: title={'center': 'Mean Age of Top 15 Scorers Over Seasons'}, xlabel='Season', ylabel='Mean Age'>)

# %% [markdown]
# # Does the age affects the goal tally?
# Let's see the effect considering features such as minutes (per 90 performance) and the season's year. But first let's check the existing correlations between variables, to have a better understandment on how to proceed.

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(COL_top15.select_dtypes(include="number").corr(), annot=True, cmap = "coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Correlation Structure and First Insights
#
# The correlation matrix highlights a strong internal consistency among performance-related variables. Goals, goals plus assists, and non-penalty goal contributions are all highly correlated with finishing rank, confirming that rank is a reasonable proxy for attacking impact within the top 15 scorers.
#
# In contrast, age shows only weak correlations with both raw output and efficiency metrics (e.g. goals per 90), and virtually no linear relationship with finishing rank. This suggests that, among elite scorers, age alone is not a dominant explanatory factor of performance differences.
#
# Instead, playing time variables such as minutes and matches played exhibit stronger associations with goal output, emphasizing availability and usage as primary drivers of seasonal performance.
#
# These patterns motivate a shift from simple correlation analysis toward regression-based approaches that can control for confounding factors and test more nuanced age effects.

# %% [markdown]
# ## Linear model: performance (goals/90) vs age
#
# OLS to estimate the relationship between `goals_per_90` and `age`, controlling for `minutes` and `season`.
# - **Question:** is there a linear association between age and production (adjusting for minutes and year)?
# - **Key interpretation:** the `age` coefficient and its statistical significance.

# %%
model = smf.ols(
    formula = "goals_per_90 ~ age + minutes + season",
    data = COL_top15
).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           goals_per_90   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     13.87
# Date:                Tue, 03 Feb 2026   Prob (F-statistic):           4.34e-08
# Time:                        18:02:15   Log-Likelihood:                 112.30
# No. Observations:                 165   AIC:                            -216.6
# Df Residuals:                     161   BIC:                            -204.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     14.1189      6.548      2.156      0.033       1.188      27.050
# ...

# %% [markdown]
# ## Linear Relationship Between Age and Scoring Efficiency
#
# The baseline OLS model estimates the relationship between age and scoring efficiency (goals per 90 minutes), while controlling for playing time and season effects.
#
# Although the model is statistically significant overall, the coefficient associated with age is small and not statistically significant at conventional levels. This indicates that, within the population of top scorers, age does not exert a strong linear influence on scoring efficiency once playing time is accounted for.
#
# The strong negative effect of minutes reflects a selection dynamic: players with higher total minutes often include those with more varied match roles, while per-90 metrics tend to favor more selective usage.
#
# Taken together, these results suggest that age-related performance decline is not clearly observable through a simple linear efficiency framework.

# %% [markdown]
# ## Age × season interaction
#
# Add `age * season` to test whether the age→goals relationship changes over time.
# - **Question:** does age matter differently in more recent years?
# - If it does not improve the model, it may suggest a non-linear change or too few data points per year.

# %%
model = smf.ols(
    formula = "goals_per_90 ~ age * season + minutes",
    data = COL_top15
).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           goals_per_90   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     10.79
# Date:                Tue, 03 Feb 2026   Prob (F-statistic):           9.11e-08
# Time:                        18:02:15   Log-Likelihood:                 113.04
# No. Observations:                 165   AIC:                            -216.1
# Df Residuals:                     160   BIC:                            -200.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     56.8074     36.290      1.565      0.119     -14.862     128.477
# ...

# %% [markdown]
# ## Testing Whether the Age Effect Changes Over Time
#
# To evaluate whether the relationship between age and scoring efficiency has evolved across seasons, an interaction term between age and season was introduced.
#
# The interaction does not significantly improve model fit, and coefficient estimates suffer from instability due to multicollinearity and limited observations per season. This suggests that age effects do not change gradually or linearly over time.
#
# Rather than indicating absence of structure, this result motivates a shift toward models that allow for discrete structural changes instead of continuous trends.

# %%
COL_top15["period"] = (COL_top15["season"]> 2020).astype(int)

mixed_model = smf.mixedlm(
    "age ~ period",
    data = COL_top15,
    groups = COL_top15["player"]
).fit()

print(mixed_model.summary())
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: age
# No. Observations: 165     Method:             REML
# No. Groups:       116     Scale:              2.6251
# Min. group size:  1       Log-Likelihood:     -446.8347
# Max. group size:  6       Converged:          Yes
# Mean group size:  1.4
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept    25.506    0.489 52.124 0.000 24.547 26.465
# period        3.957    0.513  7.717 0.000  2.952  4.962
# Group Var    18.882    3.309
# ...

# %%
m_trend = smf.ols("mean_age ~ season", data=COL_age_ts).fit()
print(m_trend.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               mean_age   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.547
# Method:                 Least Squares   F-statistic:                     13.06
# Date:                Tue, 03 Feb 2026   Prob (F-statistic):            0.00563
# Time:                        18:02:15   Log-Likelihood:                -17.886
# No. Observations:                  11   AIC:                             39.77
# Df Residuals:                       9   BIC:                             40.57
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -918.4121    261.914     -3.507      0.007   -1510.903    -325.921
# ...

# %% [markdown]
# ## Accounting for Repeated Player Appearances
#
# Because several players appear in the dataset across multiple seasons, observations are not fully independent. To account for this, a mixed-effects model with player-level random intercepts is estimated.
#
# This model focuses on age as the dependent variable and evaluates whether the post-2020 period is associated with a structural shift in the age composition of top scorers.
#
# Results indicate a statistically significant increase in average age during the post-2020 period, even after accounting for player-level heterogeneity. This finding supports the descriptive evidence that elite scorer profiles became older during this interval.

# %%
m_period = smf.ols("mean_age ~ period", data=COL_age_ts).fit()
print(m_period.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               mean_age   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     12.41
# Date:                Tue, 03 Feb 2026   Prob (F-statistic):            0.00648
# Time:                        18:02:16   Log-Likelihood:                -18.048
# No. Observations:                  11   AIC:                             40.10
# Df Residuals:                       9   BIC:                             40.89
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     26.5889      0.563     47.192      0.000      25.314      27.863
# ...

# %%
m_piecewise = smf.ols("mean_age ~ season * period", data=COL_age_ts).fit()
print(m_piecewise.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               mean_age   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     4.692
# Date:                Tue, 03 Feb 2026   Prob (F-statistic):             0.0423
# Time:                        18:02:16   Log-Likelihood:                -16.754
# No. Observations:                  11   AIC:                             41.51
# Df Residuals:                       7   BIC:                             43.10
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      -884.1683    670.908     -1.318      0.229   -2470.615     702.278
# ...

# %% [markdown]
# Let's try to assume there is no linearity and considering there is no much data points to analyze from the means, we can add robustness to the test.

# %% [markdown]
# ### Structural Change in the Age Profile of Top Scorers
#
# Regression-based trend analysis reveals a statistically significant upward trend in the average age of top scorers over time. However, given the limited number of seasonal observations, linear trend assumptions may be restrictive.
#
# To address this, a period-based model is estimated, distinguishing pre- and post-2020 seasons. The results indicate a clear structural increase in mean age during the post-2020 period.
#
# This conclusion is further supported by a non-parametric Mann–Kendall test, which confirms the presence of a statistically significant monotonic trend without relying on distributional assumptions.
#
# Together, these results provide strong evidence that the age composition of elite scorers in the Colombian league shifted upward in the post-pandemic period.

# %%
def mann_kendall_test(x):
    x = list(x)
    n = len(x)
    S = 0
    for i in range(n-1):
        for j in range(i+1, n):
            S += (x[j] > x[i]) - (x[j] < x[i])

    # var(S) 
    varS = (n*(n-1)*(2*n+5))/18
    if S > 0:
        Z = (S - 1) / math.sqrt(varS)
    elif S < 0:
        Z = (S + 1) / math.sqrt(varS)
    else:
        Z = 0.0

    p = 2 * (1 - norm.cdf(abs(Z)))
    return S, Z, p

S, Z, p = mann_kendall_test(COL_age_ts["mean_age"])
print("MK S:", S, "Z:", Z, "p-value:", p)
# Out:
# MK S: 36 Z: 2.7247463045653304 p-value: 0.006435091231559165

# %% [markdown]
# ## Main Findings
#
# The results provide consistent evidence that the age profile of top-ranked strikers in the Colombian league has shifted upward over time.
#
# Descriptive time series show a clear increase in the average age of top 15 scorers, with the highest values occurring in the post-2020 period. This pattern is statistically supported by both regression-based structural break models and a non-parametric Mann–Kendall trend test.
#
# Importantly, this shift reflects a change in **who reaches the top of the rankings**, rather than a change in the age–performance relationship itself. Linear and interaction-based performance models do not indicate a strong or worsening age-related decline in scoring efficiency among elite players.
#
# Taken together, these findings suggest that recent seasons have been characterized by greater reliance on experienced strikers at the very top of the scoring distribution, marking a compositional transformation in elite offensive profiles rather than a simple performance-driven aging effect.

# %% [markdown]
# ------

# %% [markdown]
# As of now, we need to start seeing some different features besides just the age, so I decided to create a ranking for every single player and a binary classificator to understand the era in which they are playing.

# %%
df_all = df_col.copy()
df_all = df_all.sort_values(["season", "goals"], ascending=[True, False])

df_all["rank_goals"] = (
    df_all
    .groupby("season")["goals"]
    .rank(method="first", ascending=False)
)

df_all["is_top15"] = (df_all["rank_goals"] <= 15).astype(int)
df_all["post2020"] = (df_all["season"] > 2020).astype(int)

# %% [markdown]
# ## LOWESS for a smooth curve
#
# Non-parametric smoothing of `goals_per_90` vs `age`.
# This is useful to visualize a non-linear relationship without imposing a functional form.

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess
def lowess_curve(df, frac = 0.35):
    d = df.dropna(subset=["age", "is_top15"]).copy()
    d = d[(d["minutes"]>=450)]
    z = lowess(d["goals_per_90"], d["age"], frac=frac, return_sorted=True)
    return pd.DataFrame(z, columns=["age", "g90_smooth"])

# %%
d1 = df_all[df_all["season"].between(2015,2020)]
d2 = df_all[df_all["season"].between(2021,2025)]
c1 = lowess_curve(d1)
c2 = lowess_curve(d2)

# %%
plt.figure(figsize=(10, 6))

# Curva pre-2020
plt.plot(c1["age"], c1["g90_smooth"], 
         linewidth=2.5, label="2015-2020", color="#2E86AB")

# Curva post-2020
plt.plot(c2["age"], c2["g90_smooth"], 
         linewidth=2.5, label="2021-2025", color="#A23B72")

plt.xlabel("Age", fontsize=12)
plt.ylabel("Goals per 90 (smoothed)", fontsize=12)
plt.title("Non-parametric Age-Performance Curves (LOWESS)", fontsize=14, fontweight="bold")
plt.legend(loc="best", fontsize=11)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# - The temporal increase in the average age of top-ranked scorers, formally detected by the Mann–Kendall trend test, raises the question of whether this shift reflects an age-related decline in performance or a structural change in who reaches the top of the rankings.
#
# - Non-parametric LOWESS smoothing of scoring efficiency (goals per 90) over age suggests that individual offensive output does not deteriorate sharply with age, and instead follows a smooth, non-linear pattern. This indicates that aging alone does not mechanically reduce striker productivity.
#
# - To bridge these findings, a Random Forest model is used to estimate the probability of reaching the Top 15 conditional on performance, playing time, and career context. By evaluating age effects while implicitly holding production profiles constant—captured through cluster-based archetypes—the model shows that age plays a secondary role relative to scoring output and accumulated experience.
#
# - Taken together, these results imply that the observed aging of elite scorers is driven less by individual performance decline and more by a compositional shift in the types of players who reach the top of the scoring distribution. This points to a structural transformation in elite offensive profiles rather than a purely performance-driven aging effect.

# %% [markdown]
# ## Identifying striker archetypes (unsupervised learning)
#
# So far, the analysis has focused on aggregate trends (average age over time),
# marginal effects (regressions), and predictive questions (Top-15 classification).
#
# However, these approaches do not explicitly address whether **different types of
# strikers coexist in the league**, nor how the **composition of these profiles
# has evolved over time**, not just those normally with  the best performances.
#
# To complement the previous results, we apply an **unsupervised clustering
# approach** to identify natural groupings of strikers based on their:
#
# - age,
# - minutes played,
# - scoring efficiency (goals per 90).
#
# The goal is not prediction, but interpretation:
# to uncover latent striker archetypes and study how their relative importance
# changes across seasons.

# %% [markdown]
# ## Temporal split (train/test)
#
# Split by years to avoid leakage:
# - train: seasons ≤ 2020
# - test: seasons ≥ 2021
#
# This mimics the real-world setting: predicting the “future” using the past.

# %%
features_num = ["age", "minutes"]
features_cat = [c for c in ["team", "position"] if c in df_all.columns]

# %%
train = df_all[df_all["season"]<=2020]
test = df_all[df_all["season"]>= 2021]

x_train = train[features_num + features_cat]
y_train = train["is_top15"]

x_test = test[features_num + features_cat]
y_test = test["is_top15"]

# %%
preprocess = ColumnTransformer(
    transformers = [
        ("num", SimpleImputer(strategy="mean"), features_num),
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy = "most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown = "ignore"))
        ]), features_cat)
    ]
)

rf = RandomForestClassifier(
    n_estimators = 500,
    random_state = 42,
    class_weight = "balanced",
    max_depth = None
)

pipe = Pipeline([
    ("prep", preprocess),
    ("rf", rf)
])

pipe.fit(x_train, y_train)

proba = pipe.predict_proba(x_test)[:,1]
print("ROC-AUC: ", roc_auc_score(y_test, proba))
# Out:
# ROC-AUC:  0.9549120331169444

# %%
rf_model = pipe.named_steps["rf"]

# nombres de features
feature_names = features_num.copy()

if features_cat:
    ohe = pipe.named_steps["prep"].named_transformers_["cat"].named_steps["onehot"]
    feature_names += ohe.get_feature_names_out(features_cat).tolist()

importances = rf_model.feature_importances_

imp_df = (
    pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })
    .sort_values("importance", ascending=False)
)

imp_df.head(10)
# Out:
#                       feature  importance
# 1                     minutes    0.334079
# 198               position_FW    0.132197
# 0                         age    0.112546
# 194               position_DF    0.096102
# 200            position_FW,MF    0.038182
# 203               position_MF    0.037139
# 201               position_GK    0.024408
# 197            position_DF,MF    0.012789
# 106  team_Jaguares de Córdoba    0.011856
# 205            position_MF,FW    0.011612

# %% [markdown]
# To avoid noise from sporadic appearances, the clustering is restricted to
# players with at least 300 minutes played in a season. This ensures that the
# identified profiles correspond to meaningful on-field roles rather than
# statistical outliers.

# %%
mask_fw = df_all["position"].str.contains("FW", na=False)
mask_mf_goleador = df_all["position"].str.contains("MF", na=False) & (df_all["goals"] > 4)

mask_base = (mask_fw | mask_mf_goleador) & (df_all["minutes"] >= 300)

# %%
cols_cluster = ["player","season","age","minutes","goals_per_90"]  # incluye player para merge luego
cluster_df = df_all.loc[mask_base, cols_cluster].copy()
cluster_df = cluster_df.dropna(subset=["age","minutes","goals_per_90"])
len(cluster_df)
# Out:
# 1670

# %%
X = StandardScaler().fit_transform(
    cluster_df[["age", "minutes", "goals_per_90"]]
)

# %%
kmeans = KMeans(n_clusters = 3, random_state = 42)
cluster_df["cluster"] = kmeans.fit_predict(X)

# %%
cluster_profiles = (
    cluster_df.drop(columns=["player"])
    .groupby("cluster")
    .mean()
)

cluster_profiles
# Out:
#               season        age      minutes  goals_per_90
# cluster
# 0        2020.513238  27.299389  2446.633401      0.244990
# 1        2020.113874  23.554974   843.910995      0.122592
# 2        2019.889157  28.378313  1070.132530      0.437108

# %% [markdown]
# The clustering reveals three distinct striker archetypes:
#
# - **Cluster 0 – High-minute veterans**:
#   Older players who accumulate a large number of minutes but exhibit relatively
#   low scoring efficiency. These players tend to occupy stable starting roles,
#   often contributing through experience, positioning, and tactical discipline
#   rather than pure finishing output.
#
# - **Cluster 1 – Young rotational attackers**:
#   Younger players with limited minutes and modest scoring rates. This group
#   likely represents developing prospects or squad rotation options who have
#   not yet consolidated a leading attacking role.
#
# - **Cluster 2 – Efficient veteran scorers**:
#   Older players with comparatively fewer minutes but very high goals per 90.
#   This profile corresponds to experienced finishers who maximize their output
#   when on the pitch, often relying on positioning and shot selection rather
#   than physical dominance. As well, a lot of these group may be constant starters
#   that due to their high scoring rate don't see negative effects on their per 90 metrics.

# %%
cluster_df["season"] = df_all.loc[cluster_df.index, "season"]

cluster_ts = (
    cluster_df
    .groupby(["season", "cluster"])
    .size()
    .reset_index(name="count")
)

cluster_ts["prop"] = (
    cluster_ts["count"] /
    cluster_ts.groupby("season")["count"].transform("sum")
)

cluster_ts.sort_values(["season", "cluster"]).head(15)
# Out:
#     season  cluster  count      prop
# 0     2015        0     38  0.269504
# 1     2015        1     62  0.439716
# 2     2015        2     41  0.290780
# 3     2016        0     47  0.299363
# 4     2016        1     74  0.471338
# 5     2016        2     36  0.229299
# 6     2017        0     45  0.283019
# 7     2017        1     73  0.459119
# 8     2017        2     41  0.257862
# 9     2018        0     36  0.264706
# 10    2018        1     63  0.463235
# 11    2018        2     37  0.272059
# 12    2019        0     44  0.312057
# 13    2019        1     62  0.439716
# 14    2019        2     35  0.248227

# %%
cluster_ts["season"].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025])

# %%
len(cluster_df), len(df_all)

cluster_df["season"].value_counts().sort_index()
# Out:
# season
# 2015    141
# 2016    157
# 2017    159
# 2018    136
# 2019    141
# 2020    117
# 2021    157
# 2022    140
# 2023    178
# 2024    175
# 2025    169
# Name: count, dtype: int64

# %%
plt.figure()

for c in sorted(cluster_ts["cluster"].unique()):
    data_c = cluster_ts[cluster_ts["cluster"] == c]
    plt.plot(
        data_c["season"],
        data_c["prop"],
        marker="o",
        label=f"Cluster {c}"
    )

plt.axvline(2020, linestyle="--")
plt.xlabel("Season")
plt.ylabel("Proportion of players")
plt.title("Evolution of scorer profiles by season")
plt.legend()
plt.show()

# %%
pivot = cluster_ts.pivot(
    index="season",
    columns="cluster",
    values="prop"
).fillna(0)

plt.figure()
plt.stackplot(
    pivot.index,
    pivot.T,
    labels=[f"Cluster {c}" for c in pivot.columns]
)

plt.axvline(2020, linestyle="--")
plt.xlabel("Season")
plt.ylabel("Proportion")
plt.title("Composition of scorer profiles over time")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Results and interpretation
#
# The temporal analysis reveals a clear structural pattern:
#
# - The share of **efficient veteran scorers (Cluster 2)** increases notably in
#   the post-2020 period.
# - At the same time, the proportion of **young rotational attackers (Cluster 1)**
#   stagnates or slightly declines.
# - The pandemic season (2020) acts as a visible disruption, but the post-2021
#   dynamics do not revert to the pre-2020 composition.
#
# These results suggest that the Colombian league has increasingly relied on
# older, more efficient forwards rather than younger developing profiles.
# This finding is consistent with the observed increase in the average age of
# Top-15 scorers and supports the central hypothesis of this project.

# %% [markdown]
# ## Now let's wonder
#
# We have appreciated that there are some relations between actually being an older age and being on the top scorers list of an specific year (particularly after pandemic) and that also has helped to classify the different group of attackers in the league into three different categories. However, what is the actual probability of this happening, can we predict how plausible is that a certain age in the top 15 and how what is the actual expected age for positions on the top.

# %% [markdown]
# ## Multi-class model: predicting rank (1–15) from age
#
# Here you treat `goal_rank` as a class and train a classifier.
# - **Question:** for a given age, which Top-15 positions are most likely?

# %% [markdown]
# ## Random Forest for rank
#
# A non-linear alternative to logistic regression.
# Note: this block had `pipe_rf.fit` without parentheses (so it does not train). Keep the full call so it actually runs.

# %%
def prepare_ranking_dataset(df):
    # 1. Filtro inicial: Minutos y (Posición FW o Volantes con > 3 goles)
    # Asumiendo que 'MF' es la etiqueta para volantes
    mask_fw = df["position"].str.contains("FW", na=False)
    mask_mf_goleador = df["position"].str.contains("MF", na=False) & (df["goals"] > 4)
    
    df_filtered = df[(df["minutes"] >= 300) & (mask_fw | mask_mf_goleador)].copy()

    # 2. Crear goal_rank por temporada
    # Ordenamos por temporada y goles (descendente)
    df_filtered = df_filtered.sort_values(["season", "goals"], ascending=[True, False])
    
    # Asignamos el ranking dentro de cada grupo de temporada
    df_filtered["goal_rank"] = df_filtered.groupby("season")["goals"].rank(
        method="first", ascending=False
    ).astype(int)
    
    # 3. Agrupamos a todos los que están fuera del Top 15 en una sola categoría (99)
    # Esto es crucial para que el modelo no intente predecir 100 rangos distintos
    df_filtered["rank_target"] = df_filtered["goal_rank"].apply(lambda x: x if x <= 15 else 16)
    
    return df_filtered.dropna(subset=["age","minutes","goals_per_90"])

# Uso:
df_allfw = prepare_ranking_dataset(df_col)

# %%
len(df_allfw)
# Out:
# 1670

# %%
df_allfw.head()
# Out:
#                      player  season                                     team  \
# 2992        Harold Preciado    2015                           Deportivo Cali
# 3463        Jefferson Duque    2015                        Atlético Nacional
# 930         Carlos Ibargüen    2015                                 Cortuluá
# 4710  Juan Fernando Caicedo    2015                   Independiente Medellín
# 5738         Martín Arzuaga    2015  Jaguares de Córdoba / Alianza Petrolera
#
#      position   age  matches_played  minutes  goals  assists  G+A  \
# 2992       FW  20.0            38.0   3326.0   23.0      0.0   23
# 3463       FW  27.0            28.0   1997.0   17.0      0.0   17
# 930        FW  19.0            30.0   2454.0   15.0      0.0   15
# 4710       FW  25.0            34.0   2881.0   13.0      0.0   13
# 5738       FW  33.0            27.0   1933.0   13.0      0.0   13
#
#       Performance_G-PK  goals_per_90  assists_per_90  G+A_per_90  goal_rank  \
# ...

# %%
def add_player_context(df):
    # 1. Asegurar orden cronológico para cálculos de memoria
    df = df.sort_values(['player', 'season'])
    
    # 2. Lag Features (Mirar al año pasado)
    df['prev_goals'] = df.groupby('player')['goals'].shift(1).fillna(0)
    df['prev_rank'] = df.groupby('player')['goal_rank'].shift(1).fillna(20) # 20 = fuera del top
    
    # 3. Tu idea: Experiencia acumulada en el TOP
    df['is_top'] = (df['goal_rank'] <= 15).astype(int)
    df['career_top_hits'] = df.groupby('player')['is_top'].transform(
        lambda x: x.shift(1).fillna(0).cumsum()
    )
    
    
    # 5. Target: Lo que queremos predecir (1-15, o 16 para el resto)
    df['rank_target'] = df['goal_rank'].apply(lambda x: x if x <= 15 else 16)
    
    return df

df_enriched = add_player_context(df_allfw)
df_top_enriched = df_enriched[df_enriched["goal_rank"] <= 15].copy()
df_top_enriched.head()
# Out:
#                 player  season             team position   age  \
# 32        Adrián Parra    2025  Deportes Tolima    FW,MF  28.0
# 33        Adrián Ramos    2020     América Cali       FW  34.0
# 35        Adrián Ramos    2022     América Cali       FW  36.0
# 36        Adrián Ramos    2023     América Cali       FW  37.0
# 48  Agustín Palavecino    2020   Deportivo Cali       MF  23.0
#
#     matches_played  minutes  goals  assists  G+A  Performance_G-PK  \
# 32            42.0   2352.0   10.0      3.0   13                10
# 33            12.0    973.0    5.0      1.0    6                 3
# 35            41.0   3462.0   11.0      5.0   16                 7
# 36            41.0   2388.0   12.0      8.0   20                11
# 48            16.0   1329.0    9.0      4.0   13                 4
#
#     goals_per_90  assists_per_90  G+A_per_90  goal_rank  rank_target  \
# 32          0.38            0.11        0.50         12           12
# ...

# %%
len(df_enriched)
# Out:
# 1670

# %% [markdown]
# ## Enriched features (player history)
#
# Include variables such as `prev_goals`, `prev_rank`, `career_top_hits`.
# - **Idea:** rank depends not only on age, but also on trajectory and prior performance.
# This often improves model stability.

# %%
features = ['age', 'goals', 'prev_goals', 'prev_rank', 'career_top_hits', 'minutes', 'goals_per_90']
X = df_enriched[features]
y = df_enriched['rank_target']

pipe_rf = Pipeline([
    ("clf", RandomForestClassifier(
        n_estimators=200,    # Número de árboles
        max_depth=4,         # Limitamos la profundidad para que no se aprenda de memoria a Rodallega
        random_state=42,
        class_weight='balanced'
    ))
])

# Entrenamos
pipe_rf.fit(X, y)
# Out:
# Pipeline(steps=[('clf',
#                  RandomForestClassifier(class_weight='balanced', max_depth=4,
#                                         n_estimators=200, random_state=42))])

# %%
importances = pipe_rf.named_steps['clf'].feature_importances_
feature_names = features

# Plot
plt.figure(figsize=(10, 6))
plt.barh(feature_names, importances, color='skyblue')
plt.xlabel("Relative importance")
plt.title("What factors determine the Ranking according to the model?")
plt.show()

# %%
df_cluster_enriched = (
    df_enriched
    .merge(
        cluster_df[["player", "season", "cluster"]],
        on=["player", "season"],
        how="inner"
    )
)

# %%
cluster_profiles.head()
# Out:
#               season        age      minutes  goals_per_90
# cluster
# 0        2020.513238  27.299389  2446.633401      0.244990
# 1        2020.113874  23.554974   843.910995      0.122592
# 2        2019.889157  28.378313  1070.132530      0.437108

# %%
df_cluster_enriched.head()
# Out:
#                 player  season                    team position   age  \
# 0        Abdiel Arroyo    2016         Deportes Tolima       FW  22.0
# 1  Adalberto Peñaranda    2024             Bucaramanga    MF,FW  26.0
# 2  Adalberto Peñaranda    2025             Bucaramanga    MF,FW  27.0
# 3       Adrián Arregui    2022  Independiente Medellín       MF  29.0
# 4        Adrián Balboa    2023                 Pereira       FW  29.0
#
#    matches_played  minutes  goals  assists  G+A  ...  goals_per_90  \
# 0            14.0    650.0    1.0      0.0    1  ...          0.14
# 1             8.0    301.0    0.0      1.0    1  ...          0.00
# 2            10.0    357.0    1.0      1.0    2  ...          0.25
# 3            47.0   3937.0    7.0      6.0   13  ...          0.16
# 4            12.0    835.0    4.0      1.0    5  ...          0.43
#
#    assists_per_90  G+A_per_90  goal_rank  rank_target  prev_goals  prev_rank  \
# ...

# %%
newbie_goals = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 1, 'goals'].median()
newbie_mins = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 1, 'minutes'].mean()
newbie_prev_rank = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 1, 'prev_rank'].median()
newbie_goals90 = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 1, 'goals_per_90'].mean()
newbie_career_top_hits = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 1, 'career_top_hits'].mean()
newbie_prev_goals = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 1, 'prev_goals'].median()


elite_goals = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 2, 'goals'].median()
elite_mins = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 2, 'minutes'].mean()
elite_prev_rank = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 2, 'prev_rank'].median()
elite_goals90 = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 2, 'goals_per_90'].mean()
elite_career_top_hits = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 2, 'career_top_hits'].mean()
elite_prev_goals = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 2, 'prev_goals'].median()      

theoretical_goals = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 0, 'goals'].median()
theoretical_mins = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 0, 'minutes'].mean()
theoretical_prev_rank = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 0, 'prev_rank'].median()
theoretical_goals90 = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 0, 'goals_per_90'].mean()
theoretical_career_top_hits = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 0, 'career_top_hits'].mean()
theoretical_prev_goals = df_cluster_enriched.loc[df_cluster_enriched['cluster'] == 0, 'prev_goals'].median()

print("Newbie Cluster (1):"
      f" Goals={newbie_goals}, Mins={newbie_mins}, PrevRank={newbie_prev_rank}, "
      f"Goals/90={newbie_goals90}, CareerTopHits={newbie_career_top_hits}, PrevGoals={newbie_prev_goals}"
)
print("Elite Cluster (2):"
      f" Goals={elite_goals}, Mins={elite_mins}, PrevRank={elite_prev_rank}, "
      f"Goals/90={elite_goals90}, CareerTopHits={elite_career_top_hits}, PrevGoals={elite_prev_goals}"
)
print("Theoretical Cluster (0):"
      f" Goals={theoretical_goals}, Mins={theoretical_mins}, PrevRank={theoretical_prev_rank}, "
      f"Goals/90={theoretical_goals90}, CareerTopHits={theoretical_career_top_hits}, PrevGoals={theoretical_prev_goals}"
)
# Out:
# Newbie Cluster (1): Goals=1.0, Mins=843.9109947643979, PrevRank=20.0, Goals/90=0.12259162303664921, CareerTopHits=0.058900523560209424, PrevGoals=0.0
# Elite Cluster (2): Goals=4.0, Mins=1070.132530120482, PrevRank=20.0, Goals/90=0.4371084337349397, CareerTopHits=0.43132530120481927, PrevGoals=2.0
# Theoretical Cluster (0): Goals=6.0, Mins=2446.633401221996, PrevRank=26.0, Goals/90=0.24498981670061099, CareerTopHits=0.3095723014256619, PrevGoals=2.0

# %%
# Ages from 17 to 40, which is the typical range for top scorers in our dataset
ages = np.arange(17, 41)

# profile A: the newbie (No previous goals, no hierarchy, just arrives)
profile_newbie = pd.DataFrame({
    'age': ages,
    'goals': newbie_goals,
    'prev_goals': newbie_prev_goals,
  # Asumimos que mete un poco más que el promedio
    'prev_rank': newbie_prev_rank,
    'career_top_hits': newbie_career_top_hits,
    'minutes': newbie_mins, 
    'goals_per_90': newbie_goals90
})

# profile B: the elite veteran (Comes from scoring 10 goals, previous rank 3, and has been in the top for 5 years)
profile_elite = pd.DataFrame({
    'age': ages,
    'goals': elite_goals,
    'prev_goals': elite_prev_goals*2.5,
    'prev_rank': elite_prev_rank/2,
    'career_top_hits': elite_career_top_hits*4,
    'minutes': elite_mins*2.5,
    'goals_per_90': elite_goals90
})

profile_theoretical = pd.DataFrame({
    'age': np.arange(17, 41),
    'goals': theoretical_goals,
    'prev_goals': theoretical_prev_goals, 
    'prev_rank': theoretical_prev_rank,
    'career_top_hits': theoretical_career_top_hits*2,
    'minutes': theoretical_mins,
    'goals_per_90': theoretical_goals90
})


prob_newbie = pipe_rf.predict_proba(profile_newbie)
prob_elite = pipe_rf.predict_proba(profile_elite)
prob_theoretical = pipe_rf.predict_proba(profile_theoretical)

# %%
labels = [f"Rank {int(c)}" for c in pipe_rf.classes_ if c <= 15]
indices_top15 = [i for i, c in enumerate(pipe_rf.classes_) if c <= 15]


proba_df_newbie = pd.DataFrame(
    prob_newbie[:, indices_top15], 
    index=ages, 
    columns=labels
)

# Graficamos
plt.figure(figsize=(14, 10))
sns.heatmap(proba_df_newbie, annot=True, fmt=".3f", cmap="viridis")
plt.title("Probability to access the Top 15 by Age as a Newbie")
plt.xlabel("Position in the Goals Ranking")
plt.ylabel("Age")
plt.show()

# %%
labels = [f"Rank {int(c)}" for c in pipe_rf.classes_ if c <= 15]
indices_top15 = [i for i, c in enumerate(pipe_rf.classes_) if c <= 15]


proba_df_elite = pd.DataFrame(
    prob_elite[:, indices_top15], 
    index=ages, 
    columns=labels
)

# Graficamos
plt.figure(figsize=(14, 10))
sns.heatmap(proba_df_elite, annot=True, fmt=".3f", cmap="viridis")
plt.title("Probability to access the Top 15 by Age as an Elite Veteran")
plt.xlabel("Position in the Goals Ranking")
plt.ylabel("Age")
plt.show()

# %%
labels = [f"Rank {int(c)}" for c in pipe_rf.classes_ if c <= 15]
indices_top15 = [i for i, c in enumerate(pipe_rf.classes_) if c <= 15]

proba_df_theoretical = pd.DataFrame(
    prob_theoretical[:, indices_top15], 
    index=ages, 
    columns=labels
)

# Graficamos
plt.figure(figsize=(14, 10))
sns.heatmap(proba_df_theoretical, annot=True, fmt=".3f", cmap="viridis")
plt.title("Probability to access the Top 15 by Age as a Theoretical Average Profile")
plt.xlabel("Position in the Goals Ranking")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# ### Final Interpretation and Implications
#
# The final results provide strong and coherent evidence that age alone does not determine access to elite scoring positions, but that age interacts meaningfully with experience, historical performance, and role continuity within the league.
#
# By leveraging cluster-derived striker archetypes and feeding them into an enriched Random Forest probability model, the analysis moves beyond a simplistic age–performance narrative. Instead, it highlights how career trajectory and accumulated league experience fundamentally reshape the probability landscape of finishing among the Top 15 scorers.
#
# Newcomer profiles consistently exhibit the highest probabilities at the lower end of the Top 15 distribution. This pattern is both intuitive and empirically grounded: newly integrated players face adaptation costs related to tactical systems, league tempo, and role uncertainty. While age contributes positively over time, the marginal gains for newcomers remain limited without prior top-level exposure, reinforcing the idea that early-career success is constrained more by context than raw age, but the last mentioned does provide much more capacities to overcome multiple situations and still perform.
#
# In contrast, elite veteran profiles display a markedly different probability structure. These players maintain elevated probabilities across higher-ranking positions, even at advanced ages. The results suggest that repeated exposure to elite scoring environments and sustained historical success effectively convert age into expertise rather than decline. In this sense, veteran strikers are not merely surviving in the league — they are systematically advantaged by institutional trust, tactical familiarity, and efficiency accrued over time.
#
# The theoretical average profile serves as an important baseline. It represents a realistic, league-consistent expectation: moderate access to the Top 15 across ages, but with increasingly limited probabilities of reaching the very top positions. This reinforces the central finding that elite outcomes are not driven by age trajectories alone, but by sustained performance histories that differentiate top-tier veterans from otherwise comparable players.
#
# Taken together, these results support a broader interpretation of ageism in professional football. The observed aging of top-ranked scorers is not primarily the result of declining youth performance, nor of an intrinsic advantage of age. Rather, it reflects a compositional shift in who occupies elite scoring roles, favoring players with accumulated credibility, continuity, and proven efficiency. Age, in this context, operates as a proxy for experience and when paired with historical success, it becomes a competitive asset rather than a liability.

# %%
def plot_smart_age_matrix(df_enriched, pipe_rf, features):
    # 1. Obtener probabilidades para CADA fila del dataset real
    X_total = df_enriched[features]
    # predict_proba devuelve una matriz [n_muestras, n_clases]
    proba_all = pipe_rf.predict_proba(X_total)
    
    # 2. Crear un DataFrame temporal con la Edad y las Probabilidades
    # Solo nos interesan los primeros 15 rangos
    cols_ranks = [f"Rank {i+1}" for i in range(15)]
    df_probs = pd.DataFrame(proba_all[:, :15], columns=cols_ranks)
    df_probs['age'] = df_enriched['age'].values
    
    # 3. AGRUPAR por edad y sacar el promedio de las probabilidades
    # Esto responde: "En promedio, ¿qué probabilidad tiene alguien de X años según su rendimiento?"
    matrix_data = df_probs.groupby('age').mean()
    
    # 4. Asegurar que todas las edades de 17 a 40 estén presentes (llenar con 0 si faltan)
    all_ages = np.arange(17, 41)
    matrix_data = matrix_data.reindex(all_ages).fillna(0)
    
    # 5. Graficar
    plt.figure(figsize=(16, 12))
    sns.heatmap(matrix_data, annot=True, fmt=".3f", cmap="viridis", cbar_kws={'label': 'Probabilidad Promedio'})
    
    plt.title("Matriz de Probabilidad Real: Edad vs Posición (Basado en Dataset Total + Features)")
    plt.xlabel("Posición en el Ranking")
    plt.ylabel("Edad")
    plt.show()

# Ejecución
plot_smart_age_matrix(df_enriched, pipe_rf, features)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

features = ['age', 'goals', 'prev_goals', 'prev_rank', 'career_top_hits', 'minutes']
X = df_enriched[features]
y = df_enriched['rank_target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
pipe_rf.fit(X_train, y_train)
precision_final = pipe_rf.score(X_test, y_test)
print(f"Precisión real del modelo: {precision_final:.4f}")
y_pred = pipe_rf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# Precisión real del modelo: 0.6760
#               precision    recall  f1-score   support
#
#            1       0.50      0.67      0.57         3
#            2       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         3
#            4       0.50      0.20      0.29         5
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         5
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00         2
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00         3
#           11       0.00      0.00      0.00         3
#           12       0.00      0.00      0.00         3
#           13       0.00      0.00      0.00         1
#           14       0.17      0.33      0.22         3
#           15       0.12      0.67      0.20         3
#           16       0.99      0.83      0.90       139
#
# ...
