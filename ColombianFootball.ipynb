# %% [markdown]
# # Data ingestion and cleaning
# First we import the needed libraries (a lot of them came by with the development of the script) such as requests (curl_cffi is the best to bypass modern webpages) and pandas-re in order to clean the information onto the different datasets

# %%
import sys
#"!{sys.executable} -m pip install --upgrade pip

# %%
# !{sys.executable} -m pip install lxml
# Out:
# ^C
# ...

# %%
# !{sys.executable} -m pip install beautifulsoup4 html5lib

# %%
import pandas as pd
import numpy as np
import requests
import re
import time
from io import StringIO
from curl_cffi import requests as cureq
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import os
import math
from scipy.stats import norm
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import time
from io import StringIO
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC

# %%
def fetch_fbref(url, wait=8):
    options = Options()
    options.add_argument("--start-maximized")
    options.add_argument("--disable-gpu")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--remote-allow-origins=*")
    options.add_argument("--incognito")

    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=options
    )

    try:
        driver.get(url)
        WebDriverWait(driver, 20).until(
            lambda d: d.execute_script("return document.readyState") == "complete"
        )
        time.sleep(wait)
        return driver.page_source
    finally:
        driver.quit()

# %%
url = f"https://fbref.com/en/comps/41/2025/stats/2025-Primera-A-Stats"
html = fetch_fbref(url)
tables = pd.read_html(StringIO(html))
len(tables)

# %%
def inject_commented_tables(html: str, must_contain=("stats_standard",)): #FBref hides the tables in comments instead of common table tags
    comments = re.findall(r"<!--(.*?)-->", html, flags=re.S) #looks for comments
    blocks = []
    for c in comments: #search for all comments
        if "<table" in c and all(m in c for m in must_contain): #stats_standard is their way of labelling their tables for standard metrics
            blocks.append(c)
    return html + "\n".join(blocks), blocks #html fetched tables and hidden tables

# %%
def is_player_stats_table(df: pd.DataFrame) -> bool:
    if isinstance(df.columns, pd.MultiIndex):
        cols = set(str(c).lower() for c in df.columns.get_level_values(-1))
    else:
        cols = set(str(c).lower() for c in df.columns)
    
    required_any = [
        {"player", "squad", "age"},
        {"player", "team", "age"},
        {"player", "pos", "age"},
        {"player", "position", "age"}
    ]

    return any(req.issubset(cols) for req in required_any)

# %%
url = f"https://fbref.com/en/comps/41/2025/stats/2025-Primera-A-Stats"
html = fetch_fbref(url)
html2, _ = inject_commented_tables(html, must_contain=("stats_standard",))
soup = BeautifulSoup(html2, "lxml")

table = soup.find("table", {"id": "stats_standard"})
player_stats = pd.read_html(StringIO(str(table)))[0]
player_stats.head()

# %%
tables[11].head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player             Nation                Pos
# 0                  1    José Abad Cuenú             co COL                 DF
# 1                  2        Joao Abonia             co COL              DF,MF
# 2                  3   Humberto Acevedo             co COL                 GK
# 3                  4      Felipe Acosta             co COL                 MF
# 4                  5   Sebastián Acosta             co COL                 MF
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Playing Time  \
#                Squad                Age               Born           MP
# 0             Junior                 29               1995           18
# 1         La Equidad                 24               2000           33
# 2           Llaneros                 27               1997            2
# ...

# %%
def extract_stats_standard_table(html: str) -> pd.DataFrame:
    html2, _ = inject_commented_tables(html, must_contain=("stats_standard",))
    
    soup = BeautifulSoup(html2, "lxml")
    table = soup.find("table", {"id": "stats_standard"})
    if table is None:
        return None
    
    df = pd.read_html(StringIO(str(table)))[0]
    return df

# %%
def fetch_tables(years, sleep=3):
  RAW_DIR = "./data_raw"
  os.makedirs(RAW_DIR, exist_ok=True)

  data_by_year = {}
  for year in years:
    url = f"https://fbref.com/en/comps/24/{year}/stats/" #fhttps://fbref.com/en/comps/41/{year}/stats/{year}-Primera-A-Stats"
    try:
      html = fetch_fbref(url)
    except Exception as e:
      print(f"Error fetching {year}: {e}")
      continue
    
    player_table = extract_stats_standard_table(html)

    if player_table is None:
      print(f"No player stats table found for {year}")
      continue

    filename = f"BRA_players_{year}.csv"
    filepath = os.path.join(RAW_DIR, filename)
    player_table.to_csv(filepath, index=False)
    print(f" Saved {filename} | shape = {player_table.shape}")

    data_by_year[year] = player_table

    time.sleep(sleep)

# %%
def flatten_multiindex_join_levels(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    lvl0 = df.columns.get_level_values(0)
    lvl1 = df.columns.get_level_values(1)

    new_cols = []
    for a, b in zip(lvl0, lvl1):
        if str(a).startswith("Unnamed"):
            a = ""
        else:
            a = str(a).strip().replace(" ", "_")

        b = str(b).strip().replace(" ", "_")

        new_cols.append(f"{a}_{b}" if a else b)

    df.columns = new_cols
    return df

# %%
def clean_player_stats(df_raw: pd.DataFrame, season: int) -> pd.DataFrame:
  df = df_raw.copy()

  df = flatten_multiindex_join_levels(df)


    #mapping columns into a better convention
  rename_map = {
        "Player": "player",
        "Nation": "nation",
        "Pos": "position",
        "Squad": "team",
        "Age": "age",
        "Born": "born",
        "Playing_Time_MP": "matches_played",
        "Playing_Time_Starts": "starts",
        "Playing_Time_Min": "minutes",
        "Playing_Time_90s": "nineties",
        "Performance_Gls": "goals",
        "Performance_Ast": "assists",
        "Performance_G+A": "G+A",
        "Per_90_Minutes_Gls": "goals_per_90",
        "Per_90_Minutes_Ast": "assists_per_90",
        "Per_90_Minutes_G+A": "G+A_per_90"
    }

  df = df.rename(columns=rename_map)
  #formatting columns to a numerical format
  numeric_cols = [
        "age", "born", "matches_played", "starts", "minutes", "nineties",
        "goals", "assists", "goals_per_90", "assists_per_90"
  ]

  for c in numeric_cols:
    if c in df.columns:
      df[c] = pd.to_numeric(df[c], errors="coerce")

  df["season"] = season
  print(df.columns.tolist())
  df = df[df["minutes"].fillna(0)>0]

  final_cols = [
        "player",
        "team",
        "position",
        "age",
        "matches_played",
        "minutes",
        "goals",
        "goals_per_90",
        "assists",
        "G+A",
        "assists_per_90",
        "Performance_G-PK",
        "season"
    ]

  df = df[[c for c in final_cols if c in df.columns]]
  return df

# %%
years = list(range(2024, 2014, -1))
fetch_tables(years)
# Out:
#  Saved BRA_players_2024.csv | shape = (757, 37)
#  Saved BRA_players_2023.csv | shape = (781, 37)
#  Saved BRA_players_2022.csv | shape = (791, 37)
#  Saved BRA_players_2021.csv | shape = (759, 37)
#  Saved BRA_players_2020.csv | shape = (783, 37)
#  Saved BRA_players_2019.csv | shape = (744, 37)
#  Saved BRA_players_2018.csv | shape = (767, 25)
#  Saved BRA_players_2017.csv | shape = (759, 25)
#  Saved BRA_players_2016.csv | shape = (764, 25)
#  Saved BRA_players_2015.csv | shape = (762, 25)

# %%
RAW_DIR = "./data_raw"

files = sorted([
    f for f in os.listdir(RAW_DIR)
    if f.startswith("BRA_")
])

raw_dfs = {}

for f in files:
    # FPC_player_stats_2015_raw.
    if "-" in f:
        year = int(f.split("_")[2].split("-")[1])  # FPC_player_stats_2015-2016_raw.csv
    else: 
        year = int(f.split("_")[2])   # FPC_player_stats_2015_raw.csv
    path = os.path.join(RAW_DIR, f)
    raw_dfs[year] = pd.read_csv(path, header=[0,1])

# %%
test_df = clean_player_stats(raw_dfs[2023], season=2023)
print(type(test_df))
test_df.head()
# Out:
# ['Rk', 'player', 'nation', 'position', 'team', 'age', 'born', 'matches_played', 'starts', 'minutes', 'nineties', 'goals', 'assists', 'G+A', 'Performance_G-PK', 'Performance_PK', 'Performance_PKatt', 'Performance_CrdY', 'Performance_CrdR', 'Expected_xG', 'Expected_npxG', 'Expected_xAG', 'Expected_npxG+xAG', 'Progression_PrgC', 'Progression_PrgP', 'Progression_PrgR', 'goals_per_90', 'assists_per_90', 'G+A_per_90', 'Per_90_Minutes_G-PK', 'Per_90_Minutes_G+A-PK', 'Per_90_Minutes_xG', 'Per_90_Minutes_xAG', 'Per_90_Minutes_xG+xAG', 'Per_90_Minutes_npxG', 'Per_90_Minutes_npxG+xAG', 'Matches', 'season']
# <class 'pandas.core.frame.DataFrame'>
#             player           team position   age  matches_played  minutes  \
# 0  Nicolás Acevedo          Bahia       MF  23.0            31.0   1970.0
# 1     Luiz Adriano  Internacional       FW  35.0            29.0   1330.0
# 2           Adriel         Grêmio       GK  22.0             2.0    180.0
# ...

# %%
clean_dfs = {}
RAW_DIR = "./data_clean"
os.makedirs(RAW_DIR, exist_ok=True)
for year, df_raw in raw_dfs.items():
  df_clean = clean_player_stats(df_raw, season=year)
  df_clean.to_csv(
        f"./data_clean/BRA_player_stats_{year}_clean.csv",
        index=False
  )

  clean_dfs[year] = df_clean


#
# Out:
# ['Rk', 'player', 'nation', 'position', 'team', 'age', 'born', 'matches_played', 'starts', 'minutes', 'nineties', 'goals', 'assists', 'G+A', 'Performance_G-PK', 'Performance_PK', 'Performance_PKatt', 'Performance_CrdY', 'Performance_CrdR', 'goals_per_90', 'assists_per_90', 'G+A_per_90', 'Per_90_Minutes_G-PK', 'Per_90_Minutes_G+A-PK', 'Matches', 'season']
# ['Rk', 'player', 'nation', 'position', 'team', 'age', 'born', 'matches_played', 'starts', 'minutes', 'nineties', 'goals', 'assists', 'G+A', 'Performance_G-PK', 'Performance_PK', 'Performance_PKatt', 'Performance_CrdY', 'Performance_CrdR', 'goals_per_90', 'assists_per_90', 'G+A_per_90', 'Per_90_Minutes_G-PK', 'Per_90_Minutes_G+A-PK', 'Matches', 'season']
# ...

# %%
raw_dir = "./data_joined"
os.makedirs(raw_dir, exist_ok=True)
def join_tables(tables):
  join_all = []
  for year, df in tables.items():
    if "goals" not in df.columns or "minutes" not in df.columns:
      print(f"Not found goals on {year}'s csv")
      continue
    df["season"] = year
    join_all.append(df)
  df_all = pd.concat(join_all, ignore_index=True)
  filename = "BRA_player_stats_all_seasons.csv"
  path = f"./data_joined/{filename}"
  df_all.to_csv(
        path,
        index=False
    )

  print(f"Saved {filename}")

# %%
join_tables(clean_dfs)
# Out:
# Saved BRA_player_stats_all_seasons.csv

# %% [markdown]
# ## Creation of the top 10 scorers dataset
# Basic function to obtain the amount of top scorers you want to examine. Particularly, the untie method is just taking into account which player had the most non-penalty goals, as I consider that a more proper approximation of goalscoring capacity should be based on open-play actions.

# %%
def top_scorers(clean_dfs: dict, top_n: int = 15):
  top_all = []
  for year, df in clean_dfs.items():
    if "goals" not in df.columns or "minutes" not in df.columns:
      print(f"Not found goals on {year}'s csv")
      continue
    top_df = (
        df.sort_values(
            ["goals", "Performance_G-PK", "minutes"],
            ascending=[False, False, True]
        )
        .assign(
            goal_rank=lambda x: x["goals"].rank(
                method="first", ascending=False
            )
        )
        .query("goal_rank <= @top_n")
    )
    top_all.append(top_df)

  top_all_df = pd.concat(top_all, ignore_index=True)
  filename = f"Top{top_n}_BRA_all_seasons.csv"
  path = f"./data_ready/{filename}"
  top_all_df.to_csv(
        path,
        index=False
    )

  print(f"Saved {filename}")

# %%
RAW_DIR = "./data_ready"
os.makedirs(RAW_DIR, exist_ok=True)

top_scorers(clean_dfs)
# Out:
# Saved Top15_BRA_all_seasons.csv

# %%
top15ARG_df = pd.read_csv("./data_ready/Top15_ARG_all_seasons.csv")
top15BRA_df = pd.read_csv("./data_ready/Top15_BRA_all_seasons.csv")
top15COL_df = pd.read_csv("./data_ready/Top15_FPC_all_seasons.csv")

# %%
# rango esperado (ajústalo)
expected = set(range(2015, 2026))
present = set(top15ARG_df["season"].unique())

missing = sorted(expected - present)
extra   = sorted(present - expected)

print("Missing seasons:", missing)
print("Extra seasons:", extra)
# Out:
# Missing seasons: [2015, 2017, 2018, 2022, 2024, 2025]
# Extra seasons: []

# %%
def read_goals_table_from_current_page(driver):
    html = driver.page_source
    tables = pd.read_html(StringIO(html))

    # intenta elegir la tabla de goleadores por columnas típicas
    for t in tables:
        cols = [str(c).strip().lower() for c in t.columns]

        # “goles/goals/tore” debe existir
        has_goals = any(c in cols for c in ["goles", "goals", "tore"])

        # y la tabla debe tener una columna tipo jugador
        has_player = any(c in cols for c in ["jugador", "player", "spieler"])

        if has_goals and has_player:
            return t

    # fallback: primera tabla
    return tables[0] if tables else None

# %%
def season_label_to_year(label: str) -> int | None:
    # ejemplos: "2017/2018" -> 2018, "2022" -> 2022, "2025 Apertura" -> 2025
    m = re.findall(r"(20\d{2})", label)
    if not m:
        return None
    return int(m[-1])  # el último año que aparezca

def clean_livefutbol_goals(df_raw: pd.DataFrame, season_label: str, country="ARG"):
    df = df_raw.copy()
    df.columns = [str(c).strip() for c in df.columns]

    rename_map = {
        "Spieler": "player",
        "Jugador": "player",
        "Player": "player",

        "Goles": "goals",
        "Goals": "goals",
        "Tore": "goals",

        "Elfm.": "pen_goals",
        "11m": "pen_goals",
        "Pen.": "pen_goals",
    }
    df = df.rename(columns={c: rename_map.get(c, c) for c in df.columns})

    keep = [c for c in ["player", "goals", "pen_goals"] if c in df.columns]
    df = df[keep].copy()

    for c in ["goals", "pen_goals"]:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce").fillna(0).astype(int)

    df["season"] = season_label_to_year(season_label)
    df["country"] = country
    return df.dropna(subset=["season"])

# %%
def top15_from_livefutbol(driver, season_label: str, url: str, country="ARG"):
    driver.get(url)
    time.sleep(0.8)

    raw = read_goals_table_from_current_page(driver)
    if raw is None:
        return None

    df = clean_livefutbol_goals(raw, season_label, country=country)
    df = df.sort_values(["goals", "pen_goals"], ascending=False).head(30).copy()
    df["goal_rank"] = range(1, len(df) + 1)
    return df

# %%
def top15_aggregate_two_stages(driver, season_label: str, url: str, country="ARG"):
    driver.get(url)

    raw = read_goals_table_from_current_page(driver)
    if raw is None or raw.empty:
        return None

    df = clean_livefutbol_goals(raw, season_label, country=country)
    df = df.sort_values(["goals", "pen_goals"], ascending=False).head(15).copy()
    df["goal_rank"] = range(1, len(df) + 1)
    return df

# %%
def make_driver(headless=False):
    options = Options()
    if headless:
        options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-gpu")
    options.add_argument("--incognito")
    options.add_argument("--window-size=1400,900")
    return webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
SEASONS = [
    ("2015", "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se16954/2015/statistics-goals/"),
    ("2016/2017", "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se21890/2016-2017/statistics-goals/"),
    ("2017/2018", "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se24540/2017-2018/statistics-goals/"),
    ("2022",      "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se45774/2022/statistics-goals/"),
    ("2024",      "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se69263/2024/statistics-goals/"),
    ("2025 Apertura", "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se84014/2025-apertura/statistics-goals/"),
    ("2025 Clausura", "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se95472/2025-clausura/statistics-goals/"),
]

# %%
def split_player_team_simple(s: str):
    """
    De un string tipo:
    'D. BenedettoDarío BenedettoBoca Juniors'
    devuelve:
    ('Darío Benedetto', 'Boca Juniors')
    """
    if not isinstance(s, str):
        return None, None

    # palabras que empiezan en mayúscula (incluye acentos)
    words = re.findall(r"[A-ZÁÉÍÓÚÑ][a-záéíóúñ]+", s)

    if len(words) < 3:
        return s.strip(), None

    # jugador = 2ª y 3ª palabra
    player = " ".join(words[1:3])

    # team = desde la 5ª palabra en adelante (si existe)
    if len(words) >= 5:
        team = " ".join(words[3:])
    else:
        team = words[-1]
    
    return player, team

# %%
driver = make_driver(headless=False)

results = []
for label, url in SEASONS:
    df = top15_from_livefutbol(driver, label, url, country="ARG")
    if df is None or df.empty:
        print("❌ Falló:", label)
        continue
    results.append(df)

driver.quit()

final_df = pd.concat(results, ignore_index=True)
final_df[["player", "team"]] = final_df["player"].apply(
    lambda x: pd.Series(split_player_team_simple(x))
)

# %%
final_df["age"] = pd.NA
final_df.head()
# Out:
#                 player  goals  pen_goals  season country  goal_rank  \
# 0          Marco Rubén     21          5    2015     ARG          1
# 1    Leandro Fernández     15          4    2015     ARG          2
# 2       Claudio Bieler     14          7    2015     ARG          3
# 3  Alejandro Gagliardi     11          1    2015     ARG          4
# 4   Fernando Cavenaghi     11          0    2015     ARG          5
#
#               team   age
# 0  Rosario Central  <NA>
# 1       Godoy Cruz  <NA>
# 2          Quilmes  <NA>
# 3    Nueva Chicago  <NA>
# 4      River Plate  <NA>

# %%
final_df.to_csv("./data_ready/Top15_ARG_livefutbol_all_seasons.csv", index=False)

# %%
birth_year_map = {
    # ya tenías
    "José Sand": 1980,
    "Darío Benedetto": 1990,
    "Sebastián Driussi": 1996,
    "Ramón Ábila": 1990,
    "Fernando Cavenaghi": 1983,
    "Marco Rubén": 1986,
    "Carlos Luna": 1982,
    "Ignacio Scocco": 1985,
    "Miguel Borja": 1993,
    "Mateo Retegui": 1999,
    "Claudio Bieler": 1982,

    # añadidos (muy conocidos)
    "Lucas Alario": 1992,
    "Gustavo Bou": 1990,
    "Darío Cvitanich": 1984,
    "Mariano Pavone": 1982,
    "Nicolás Blandi": 1990,
    "Emiliano Rigoni": 1993,
    "Fernando Zampedri": 1988,
    "Lautaro Martínez": 1997,
    "Mauro Zárate": 1987,
    "Santiago García": 1990,
    "Martín Cauteruccio": 1987,
    "Walter Bou": 1993,
    "Ignacio Malcorra": 1987,
    "Franco Jara": 1988,
    "Guido Carrillo": 1991,
    "Leandro Fernández": 1991,
    "Maximiliano Rodríguez": 1981,
    "Jonathan Calleri": 1993,
    "Marcelo Larrondo": 1987,
    "Enrique Triverio": 1988,
    "Lucas Albertengo": 1991,
    "Gervasio Núñez": 1986,
    "Fernando Coniglio": 1991,
    "Sebastián Palacios": 1992,
    "Javier Correa": 1994,
    "Sebastián Ribas": 1988,
    "Franco Soldano": 1994,
    "Fernando Márquez": 1991,
    "Ignacio Pussetto": 1995,
    "Cristian Lema": 1988,
    "Nicolás Fernández": 1996,
    "Enzo Copetti": 1998,
    "Adam Bareiro": 1996,
    "Renzo Lopez": 1994,
    "Blas Armoa": 1998,
    "Cristian Colmán": 1994,
    "Luis Rodríguez": 1991,
    "Mauro Boselli": 1981,
    "Ramiro Carrera": 1993,
    "Alejandro Martinez": 1992,
    "Braian Romero": 1991,
    "Mateo Pellegrino": 2000,
    "Milton Giménez": 1994,
    "Claudio Aquino": 1984,
    "Gabriel Avalos": 1993,
    "Jonathan Herrera": 1989,
    "Salomón Rodríguez": 1990,
    "Facundo Colidio": 1998,
    "Miguel Merentiel": 1996,
    "Bruno Barticciotto": 2001,
    "Adrián Martinez": 1992,
    "Tomás Molina": 1995,
    "Andrés Vombergar": 1994,
    "Elías Torres": 2000,
    "Jhonatan Candia": 1995,
    "Matko Miljevic": 1998,
    "Leonardo Heredia": 1996,
    "Alex Luna": 2002,
    "Facundo Bruera": 1998,
    "Ignacio Russo": 2001,
    "Gaston Togni": 1997,
    "Ronaldo Martinez": 1996,
    "Maria Angel": 1997,
    "Marcelo Torres": 1993,
    "Rodrigo Castillo": 1995,
    "Alexis Cuello": 1994,
    "Giuliano Galoppo": 1996,
    "Alejo Veliz": 2000,
    "Abiel Osorio": 1997,
    "Agustín Auzmendi": 1997,
    "Felipe Loyola": 1999,
    "Ángel Di María": 1988,
    "Juan Miritello": 1999,
    "Alejandro Gagliardi": 1989,
}

# %%
Seasons2025 = [
    ("2025 Apertura", "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se84014/2025-apertura/statistics-goals/"),
    ("2025 Clausura", "https://www.livefutbol.com/competition/co103/argentina-superliga-argentina/se95472/2025-clausura/statistics-goals/"),
]
Arg2025_df = None
results2 = []
driver = make_driver(headless=False)
for label, url in Seasons2025:
    df = top15_from_livefutbol(driver, label, url, country="ARG")
    if df is None or df.empty:
        print("❌ Falló:", label)
        continue
    print("✅ Éxito:", label)
    results2.append(df)

driver.quit()

Arg2025_df = pd.concat(results2, ignore_index=True)
Arg2025_df[["player", "team"]] = Arg2025_df["player"].apply(
    lambda x: pd.Series(split_player_team_simple(x))
)
# Out:
# ✅ Éxito: 2025 Apertura
# ✅ Éxito: 2025 Clausura

# %%
df_2025_sum = (
    Arg2025_df
    .groupby("player", as_index=False)
    .agg({
        "goals": "sum",
        "pen_goals": "sum",
        "team": "first",   # ok para 2025
        "country": "first"
    })
)
df_2025_sum = df_2025_sum.sort_values(["goals", "pen_goals"], ascending=False).head(15).copy()
df_2025_sum.head(15)

# %%
df_2025_sum.to_csv("./data_ready/Top15_ARG_livefutbol_2025_aggregated.csv", index=False)
df_2025_sum.head(30)
# Out:
#                player  goals  pen_goals                team country
# 18     Gabriel Ávalos     12          2       Independiente     ARG
# 41   Miguel Merentiel     11          1        Boca Juniors     ARG
# 45   Rodrigo Castillo     11          0   Gimnasia La Plata     ARG
# 28   Jonathan Herrera     10          2   Deportivo Riestra     ARG
# 14     Facundo Bruera     10          0    Barracas Central     ARG
# 25      Ignacio Russo     10          0               Tigre     ARG
# 1     Adrián Martínez      9          1         Racing Club     ARG
# 42     Milton Giménez      9          0        Boca Juniors     ARG
# 8       Braian Romero      8          1     Vélez Sarsfield     ARG
# 30     Juan Miritello      8          0    Defensa Justicia     ARG
# 43  Nicolás Fernández      8          0    Belgrano Córdoba     ARG
# 47   Ronaldo Martínez      8          0            Platense     ARG
# 50       Tomás Molina      8          0  Argentinos Juniors     ARG
# ...

# %%
final_df = pd.read_csv("./data_ready/Top15_ARG_livefutbol_all_seasons.csv")

# %%
final_df.query("season == 2025").head()
# Out:
#               player  goals  pen_goals  season country  goal_rank  \
# 75    Gabriel Ávalos   12.0          2  2025.0     ARG        1.0
# 76  Miguel Merentiel   11.0          1  2025.0     ARG        2.0
# 77  Rodrigo Castillo   11.0          0  2025.0     ARG        3.0
# 78  Jonathan Herrera   10.0          2  2025.0     ARG        4.0
# 79    Facundo Bruera   10.0          0  2025.0     ARG        5.0
#
#                  team   age
# 75      Independiente  None
# 76       Boca Juniors  None
# 77  Gimnasia La Plata  None
# 78  Deportivo Riestra  None
# 79   Barracas Central  None

# %%
final_df["birth_year"] = final_df["player"].map(birth_year_map)
final_df["age"] = final_df["season"] - final_df["birth_year"]
final_df.drop(columns=["birth_year"], inplace=True)
final_df.to_csv("./data_ready/Top15_ARG_livefutbol_all_seasons_with_age.csv", index=False)
final_df.head(30)
# Out:
#                    player  goals  pen_goals  season country  goal_rank  \
# 0             Marco Rubén   21.0          5  2015.0     ARG        1.0
# 1       Leandro Fernández   15.0          4  2015.0     ARG        2.0
# 2          Claudio Bieler   14.0          7  2015.0     ARG        3.0
# 3     Alejandro Gagliardi   11.0          1  2015.0     ARG        4.0
# 4      Fernando Cavenaghi   11.0          0  2015.0     ARG        5.0
# 5   Maximiliano Rodríguez   10.0          2  2015.0     ARG        6.0
# 6        Jonathan Calleri   10.0          0  2015.0     ARG        7.0
# 7      Martín Cauteruccio   10.0          0  2015.0     ARG        8.0
# 8        Ignacio Malcorra    9.0          3  2015.0     ARG        9.0
# 9        Enrique Triverio    9.0          2  2015.0     ARG       10.0
# 10       Marcelo Larrondo    9.0          1  2015.0     ARG       11.0
# 11            Ramón Ábila    9.0          0  2015.0     ARG       12.0
# ...

# %% [markdown]
# I just wanted to see if there was any sort of coefficient of correlation that could help me prove the main point of the investigation.

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(top15COL_df.select_dtypes(include="number").corr(), annot=True, cmap = "coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %%
def build_age_timeseries(df, top_n = 15, rank_col="goals"):
  df_sorted = df.sort_values(["season", rank_col], ascending=[True, False])

  df_top = df_sorted.groupby("season", as_index=False).head(top_n)

  ts = (
      df_top.groupby("season", as_index=False)
      .agg(
          mean_age =("age","mean"),
          median_age = ("age", "median"),
          p75_age = ("age", lambda s: s.quantile(0.75)),
          n_players = ("player","nunique")
      ).sort_values("season")
  )
  return ts, df_top

ARG_age_ts, Arg_top_df = build_age_timeseries(top15ARG_df)
BRA_age_ts, Bra_top_df = build_age_timeseries(top15BRA_df)
COL_age_ts, Col_top_df = build_age_timeseries(top15COL_df)

ARG_age_ts.head()
# Out:
#    season   mean_age  median_age  p75_age  n_players
# 0    2016  26.266667        27.0     27.5         15
# 1    2019  28.466667        28.0     31.0         15
# 2    2020  28.266667        28.0     31.5         15
# 3    2021  27.400000        27.0     30.5         15
# 4    2023  27.600000        26.0     31.0         15

# %%
age_ts["period"] = (age_ts["season"] > 2020).astype(int)

# %%
plt.figure()
plt.plot(age_ts["season"], age_ts["mean_age"],marker="o")
plt.axvline(2020, linestyle="--")
plt.xlabel("Season")
plt.ylabel("Mean Age (Top 15 Scorers)")
plt.title("Age trend of top 15 scorers by season")
plt.show()

# %%
plt.figure()
plt.plot(age_ts["season"], age_ts["median_age"], marker="o", label="Median")
plt.plot(age_ts["season"], age_ts["p75_age"], marker="o", label="75th percentile")
plt.axvline(2020, linestyle="--")
plt.xlabel("Season")
plt.ylabel("Age")
plt.title("Distribution shift (Top 15 scorers)")
plt.legend()
plt.show()

# %% [markdown]
# # Does the age affects the goal tally?
# Let's see the effect considering features such as minutes (per 90 performance) and the season's year

# %%
model = smf.ols(
    formula = "goals_per_90 ~ age + minutes + season",
    data = top15_df
).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           goals_per_90   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.225
# Method:                 Least Squares   F-statistic:                     16.90
# Date:                Sun, 18 Jan 2026   Prob (F-statistic):           1.37e-09
# Time:                        19:42:18   Log-Likelihood:                 103.11
# No. Observations:                 165   AIC:                            -198.2
# Df Residuals:                     161   BIC:                            -185.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.9541      7.116      1.680      0.095      -2.099      26.007
# ...

# %% [markdown]
# We can appreciate that for sure the model is statisitically significant (F-statistic value is less than 0.05) and there is a slight increase with age if also goals do. However, we are trying to see if there has been an increase within the avg age of top scorers through time.
#
# Therefore, it's needed to change the formula to consider how the goals-age relationship has changed through time, not if the goals are affected by age (as if the effect was the same each season)
#
# The new formula considers this by doing: \begin{equation}
# \text{goals_per_90} \sim \text{age} \times \text{season} + \text{minutes}
# \end{equation}

# %%
model = smf.ols(
    formula = "goals_per_90 ~ age * season + minutes",
    data = top15_df
).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           goals_per_90   R-squared:                       0.245
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     12.97
# Date:                Sun, 18 Jan 2026   Prob (F-statistic):           3.60e-09
# Time:                        19:42:21   Log-Likelihood:                 103.70
# No. Observations:                 165   AIC:                            -197.4
# Df Residuals:                     160   BIC:                            -181.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     53.0934     39.180      1.355      0.177     -24.283     130.470
# ...

# %% [markdown]
# Sadfully the interaction between age and season, didn't lead to any sort of important improvement. Hence, there is a need for a more adequate model, in this case considering the 2nd note.
#
# Let's try a mixed linear model, as in reality a lot of the variables are strongly related due to players having multiple entries and hence seasons not being completely independent. This aspect is fundamental in this context, how do we expect performance from the last season to not have any sort of effect in the next season? Or how do we expect that a player that left the league as a top scorer and returns to not have somewhat a decent performance? Although there might be some other variables such as the team position the previous year, we can skip that as for now.

# %%
top15_df["period"] = (top15_df["season"]> 2020).astype(int)

mixed_model = smf.mixedlm(
    "age ~ period",
    data = top15_df,
    groups = top15_df["player"]
).fit()

print(mixed_model.summary())
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: age
# No. Observations: 165     Method:             REML
# No. Groups:       112     Scale:              2.5679
# Min. group size:  1       Log-Likelihood:     -437.8818
# Max. group size:  6       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept    25.438    0.466 54.595 0.000 24.525 26.351
# period        4.090    0.470  8.708 0.000  3.169  5.011
# Group Var    17.105    2.918
# ...

# %%
m_trend = smf.ols("mean_age ~ season", data=age_ts).fit()
print(m_trend.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               mean_age   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.595
# Method:                 Least Squares   F-statistic:                     15.70
# Date:                Sun, 18 Jan 2026   Prob (F-statistic):            0.00329
# Time:                        19:42:34   Log-Likelihood:                -18.347
# No. Observations:                  11   AIC:                             40.69
# Df Residuals:                       9   BIC:                             41.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1054.3879    273.129     -3.860      0.004   -1672.249    -436.527
# ...

# %%
m_period = smf.ols("mean_age ~ period", data=age_ts).fit()
print(m_period.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               mean_age   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     11.13
# Date:                Sun, 18 Jan 2026   Prob (F-statistic):            0.00872
# Time:                        19:42:36   Log-Likelihood:                -19.473
# No. Observations:                  11   AIC:                             42.95
# Df Residuals:                       9   BIC:                             43.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     26.4000      0.641     41.165      0.000      24.949      27.851
# ...

# %%
m_piecewise = smf.ols("mean_age ~ season * period", data=age_ts).fit()
print(m_piecewise.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               mean_age   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     5.173
# Date:                Sun, 18 Jan 2026   Prob (F-statistic):             0.0339
# Time:                        19:42:38   Log-Likelihood:                -17.473
# No. Observations:                  11   AIC:                             42.95
# Df Residuals:                       7   BIC:                             44.54
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1226.3714    716.265     -1.712      0.131   -2920.069     467.326
# ...

# %% [markdown]
# Let's try to assume there is no linearity and considering there is no much data points to analyze from the means, we can add robustness to the test.

# %%
def mann_kendall_test(x):
    x = list(x)
    n = len(x)
    S = 0
    for i in range(n-1):
        for j in range(i+1, n):
            S += (x[j] > x[i]) - (x[j] < x[i])

    # var(S) sin corrección por empates (si hay muchos empates, lo ajustamos luego)
    varS = (n*(n-1)*(2*n+5))/18
    if S > 0:
        Z = (S - 1) / math.sqrt(varS)
    elif S < 0:
        Z = (S + 1) / math.sqrt(varS)
    else:
        Z = 0.0

    p = 2 * (1 - norm.cdf(abs(Z)))
    return S, Z, p

S, Z, p = mann_kendall_test(age_ts["mean_age"])
print("MK S:", S, "Z:", Z, "p-value:", p)
# Out:
# MK S: 34 Z: 2.569046515733026 p-value: 0.010197876776240289

# %% [markdown]
# Now, other doubts can be covered. How can we determine if "age" emerges as a relevant variable to explain who may have the honour to be in the top scorers each season?

# %%
df_all = pd.read_csv("./data_joined/FPC_player_stats_all_seasons.csv")
df_all = df_all.sort_values(["season", "goals"], ascending=[True, False])

df_all["rank_goals"] = (
    df_all
    .groupby("season")["goals"]
    .rank(method="first", ascending=False)
)

df_all["is_top15"] = (df_all["rank_goals"] <= 15).astype(int)

# %%
features_num = ["age", "minutes"]
features_cat = [c for c in ["team", "position"] if c in df_all.columns]

# %% [markdown]
# For this case, the split is completely arbitrary. The period in which I consider the change may had started was after pandemic or at the beginning of this decade.

# %%
train = df_all[df_all["season"]<=2020]
test = df_all[df_all["season"]>= 2021]

x_train = train[features_num + features_cat]
y_train = train["is_top15"]

x_test = test[features_num + features_cat]
y_test = test["is_top15"]

# %%
preprocess = ColumnTransformer(
    transformers = [
        ("num", SimpleImputer(strategy="mean"), features_num),
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy = "most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown = "ignore"))
        ]), features_cat)
    ]
)

rf = RandomForestClassifier(
    n_estimators = 500,
    random_state = 42,
    class_weight = "balanced",
    max_depth = None
)

pipe = Pipeline([
    ("prep", preprocess),
    ("rf", rf)
])

pipe.fit(x_train, y_train)

proba = pipe.predict_proba(x_test)[:,1]
print("ROC-AUC: ", roc_auc_score(y_test, proba))
# Out:
# ROC-AUC:  0.9628723495579019

# %%
rf_model = pipe.named_steps["rf"]

# nombres de features
feature_names = features_num.copy()

if features_cat:
    ohe = pipe.named_steps["prep"].named_transformers_["cat"].named_steps["onehot"]
    feature_names += ohe.get_feature_names_out(features_cat).tolist()

importances = rf_model.feature_importances_

imp_df = (
    pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })
    .sort_values("importance", ascending=False)
)

imp_df.head(10)
# Out:
#                      feature  importance
# 1                    minutes    0.391681
# 45               position_FW    0.111953
# 0                        age    0.102500
# 41               position_DF    0.100739
# 47            position_FW,MF    0.041010
# 50               position_MF    0.030093
# 48               position_GK    0.024877
# 26  team_Jaguares de Córdoba    0.014312
# 44            position_DF,MF    0.013119
# 52            position_MF,FW    0.012895

# %%
cluster_df = (
    df_all[
        ["season", "age", "minutes", "goals_per_90"]
    ]
    .dropna()
)

# %%
cluster_df = cluster_df[cluster_df["minutes"] >= 300]

# %%
X = StandardScaler().fit_transform(
    cluster_df[["age", "minutes", "goals_per_90"]]
)

# %%
kmeans = KMeans(n_clusters = 3, random_state = 42)
cluster_df["cluster"] = kmeans.fit_predict(X)

# %%
cluster_profiles = (
    cluster_df
    .groupby("cluster")
    .mean()
)

cluster_profiles
# Out:
#               season        age      minutes  goals_per_90
# cluster
# 0        2020.267201  27.425518  2568.840347      0.071864
# 1        2019.974660  22.716489   922.456482      0.053206
# 2        2020.005845  29.730074  1035.681190      0.195207

# %%
cluster_df["season"] = df_all.loc[cluster_df.index, "season"]

cluster_ts = (
    cluster_df
    .groupby(["season", "cluster"])
    .size()
    .reset_index(name="count")
)

cluster_ts["prop"] = (
    cluster_ts["count"] /
    cluster_ts.groupby("season")["count"].transform("sum")
)

cluster_ts.sort_values(["season", "cluster"]).head(15)
# Out:
#     season  cluster  count      prop
# 0     2015        0    145  0.259857
# 1     2015        1    246  0.440860
# 2     2015        2    167  0.299283
# 3     2016        0    125  0.217770
# 4     2016        1    278  0.484321
# 5     2016        2    171  0.297909
# 6     2017        0    134  0.238434
# 7     2017        1    254  0.451957
# 8     2017        2    174  0.309609
# 9     2018        0    142  0.259598
# 10    2018        1    228  0.416819
# 11    2018        2    177  0.323583
# 12    2019        0    140  0.249110
# 13    2019        1    261  0.464413
# 14    2019        2    161  0.286477

# %%
cluster_ts["season"].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025])

# %%
# 1. Cuántas filas sobreviven
len(cluster_df), len(df_all)

# 2. Qué temporadas hay realmente
cluster_df["season"].value_counts().sort_index()
# Out:
# season
# 2015    558
# 2016    574
# 2017    562
# 2018    547
# 2019    562
# 2020    426
# 2021    547
# 2022    550
# 2023    590
# 2024    577
# 2025    609
# Name: count, dtype: int64

# %%
plt.figure()

for c in sorted(cluster_ts["cluster"].unique()):
    data_c = cluster_ts[cluster_ts["cluster"] == c]
    plt.plot(
        data_c["season"],
        data_c["prop"],
        marker="o",
        label=f"Cluster {c}"
    )

plt.axvline(2020, linestyle="--")
plt.xlabel("Season")
plt.ylabel("Proportion of players")
plt.title("Evolution of scorer profiles by season")
plt.legend()
plt.show()

# %%
pivot = cluster_ts.pivot(
    index="season",
    columns="cluster",
    values="prop"
).fillna(0)

plt.figure()
plt.stackplot(
    pivot.index,
    pivot.T,
    labels=[f"Cluster {c}" for c in pivot.columns]
)

plt.axvline(2020, linestyle="--")
plt.xlabel("Season")
plt.ylabel("Proportion")
plt.title("Composition of scorer profiles over time")
plt.legend(loc="upper left")
plt.show()

# %%
cluster_profiles.plot(kind="bar")
plt.title("Average profile per cluster")
plt.ylabel("Value")
plt.show()
